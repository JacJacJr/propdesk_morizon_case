# %% [markdown]
# ### Import required packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read prepared data

# %%
housing_data_path = "all_platforms_data.csv"
df_housing = pd.read_csv(filepath_or_buffer=housing_data_path, delimiter=",", header=0, encoding="utf-8")

df_housing.sample(2)
# Out:
#        is_primary_nan  total_area  basement  elevator  balcony  \
# 11245               0       73.90         0         0        1
# 4455                0       71.47         0         1        1
#
#        property_level  heating_type_nan  balcony_nan  row_price_m2  \
# 11245               1                 1            0         13500
# 4455                5                 1            0         16600
#
#        total_property_level  ...  elevator_nan        id  is_parking  \
# 11245                     4  ...             1  64744584           1
# 4455                      6  ...             0  65221182           1
#
#        no_rooms district_norm  building_type  property_level_nan  \
# 11245         3       mokotow       tenement                   0
# 4455          3       UNKNOWN        UNKNOWN                   0
#
#        building_year_nan  portal_name basement_nan
# 11245                  1       otodom            1
# 4455                   0       otodom            1
#
# ...

# %% [markdown]
# ### Analyze data statistics

# %%
df_housing.columns
# Out:
# Index(['is_primary_nan', 'total_area', 'basement', 'elevator', 'balcony',
#        'property_level', 'heating_type_nan', 'balcony_nan', 'row_price_m2',
#        'total_property_level', 'parking_nan', 'url', 'building_type_nan',
#        'building_year', 'heating_type', 'price', 'is_primary',
#        'total_property_level_nan', 'elevator_nan', 'id', 'is_parking',
#        'no_rooms', 'district_norm', 'building_type', 'property_level_nan',
#        'building_year_nan', 'portal_name', 'basement_nan'],
#       dtype='object')

# %%
df_housing.describe()
# Out:
#        is_primary_nan    total_area      basement      elevator       balcony  \
# count    18883.000000  18883.000000  18883.000000  18883.000000  18883.000000
# mean         0.036382     54.650618      0.348515      0.564370      0.728221
# std          0.187244     17.239752      0.476513      0.495852      0.444888
# min          0.000000     18.000000      0.000000      0.000000      0.000000
# 25%          0.000000     42.000000      0.000000      0.000000      0.000000
# 50%          0.000000     53.300000      0.000000      1.000000      1.000000
# 75%          0.000000     65.190000      1.000000      1.000000      1.000000
# max          1.000000    104.800000      1.000000      1.000000      1.000000
#
#        property_level  heating_type_nan   balcony_nan  row_price_m2  \
# count    18883.000000      18883.000000  18883.000000  18883.000000
# mean         8.726844          0.364031      0.099666  17578.946142
# ...

# %%
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18883 entries, 0 to 18882
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   is_primary_nan            18883 non-null  int64
#  1   total_area                18883 non-null  float64
#  2   basement                  18883 non-null  int64
#  3   elevator                  18883 non-null  int64
#  4   balcony                   18883 non-null  int64
#  5   property_level            18883 non-null  int64
#  6   heating_type_nan          18883 non-null  int64
#  7   balcony_nan               18883 non-null  int64
#  8   row_price_m2              18883 non-null  int64
#  9   total_property_level      18883 non-null  int64
#  10  parking_nan               18883 non-null  int64
#  11  url                       18883 non-null  object
#  12  building_type_nan         18883 non-null  int64
#  13  building_year             18883 non-null  int64
# ...

# %%
df_housing["price"].describe()
# Out:
# count    1.888300e+04
# mean     9.450459e+05
# std      3.380569e+05
# min      2.850000e+05
# 25%      7.000000e+05
# 50%      8.590000e+05
# 75%      1.122000e+06
# max      2.142162e+06
# Name: price, dtype: float64

# %%
df_housing.isna().sum()
# Out:
# is_primary_nan              0
# total_area                  0
# basement                    0
# elevator                    0
# balcony                     0
# property_level              0
# heating_type_nan            0
# balcony_nan                 0
# row_price_m2                0
# total_property_level        0
# parking_nan                 0
# url                         0
# building_type_nan           0
# building_year               0
# heating_type                0
# price                       0
# is_primary                  0
# total_property_level_nan    0
# elevator_nan                0
# id                          0
# is_parking                  0
# no_rooms                    0
# district_norm               0
# building_type               0
# property_level_nan          0
# building_year_nan           0
# portal_name                 0
# basement_nan                0
# dtype: int64

# %% [markdown]
# ### Features analysis

# %% [markdown]
# ##### Correlation Heatmap

# %%
# Convert categorical data to numerical data
import numpy as np
df_housing_numeric = df_housing.select_dtypes(include=[np.number])

correlations = df_housing_numeric.corr()

plt.figure(figsize=(20, 20))
sns.heatmap(correlations, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.3, linecolor='black', annot_kws={"size": 8})
plt.title('Correlation Heatmap', fontsize=12)
plt.xticks(fontsize=8, rotation=45)
plt.yticks(fontsize=8)
plt.show()

# %% [markdown]
# ##### Price distribution

# %%
sns.boxplot(x=df_housing["price"])
# Out:
# <Axes: xlabel='price'>

# %%
# Plotting the histogram
### Params
price_min = 100000
price_max = df_housing['price'].max()
bin_width = 100000
bins = range(int(price_min), int(price_max) + int(bin_width), int(bin_width))

### Plot
plt.figure(figsize=(14, 8))
sns.histplot(df_housing['price'], bins=bins, kde=False)

plt.title('Distribution of Property Prices')
plt.xlabel('Price [PLN]')
plt.ylabel('Frequency')

### Update labels to be in 100k PLN
labels = [f'{(label/1000)}k' for label in bins]
plt.xticks(bins, labels, rotation=45)

plt.show()

# %% [markdown]
# ##### Price vs Total Area

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='total_area', y='price', data=df_housing)
plt.title('Price vs Total Area')
plt.xlabel('Total Area (m²)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ##### Price vs Building Year

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='building_year', y='price', data=df_housing)
plt.title('Price vs Building Year')
plt.xlabel('Building Year')
plt.ylabel('Price')

plt.xlim(df_housing['building_year'].min(), df_housing['building_year'].max())
plt.ylim(100000, df_housing['price'].max())
plt.yticks(range(100000, int(df_housing['price'].max()) + 100000, 100000))

plt.show()

# %% [markdown]
# ##### Price by District

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='district_norm', y='price', data=df_housing)
plt.title('Price by District')
plt.xlabel('District')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Price by building type

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='building_type', y='price', data=df_housing)
plt.title('Price by Building Type')
plt.xlabel('Building Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Validate how do the categorical attrbiutes contribute to price

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='heating_type', y='price', data=df_housing)
plt.title('Price by Heating Type')
plt.xlabel('Heating Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
