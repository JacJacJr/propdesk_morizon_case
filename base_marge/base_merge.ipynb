# %% [markdown]
# # Intro

# %% [markdown]
# Import of used libraries

# %%
import re
import unidecode
import unicodedata
import pandas as pd
import numpy as np
from typing import List

# %% [markdown]
# Importing dictionary from districts_subdistricts_dict.py for normalization of districts

# %%
from districts_subdistricts_dict import districts_subdistricts_dict

# %% [markdown]
# Look on dataframes from property platforms (scraped, example of morizon scraper in repo):
#
#     - morizon
#     - otodom
#     - no (Nieruchomosci Online)

# %% [markdown]
# ## Class collecting dataframes from portal databases, storing methods used for all sources

# %%
class PortalData:

    def __init__(self, platform_name: str) -> None:

        self.platform_name = platform_name
        self.file_path = f"data/{platform_name}/{platform_name}.csv"
        self.cleaned_file_path = f"data/archive/{platform_name}/{platform_name}.csv"
        self.data_frame = pd.DataFrame()

    @property
    def df(self):
        return self.data_frame
    
    @df.setter
    def df(self, value):
        self._df = value
        
    def load_data(self) -> pd.DataFrame:
        self.data_frame = pd.read_csv(self.file_path)
        return self.data_frame

    def show_dataframe(self) -> pd.DataFrame:
        return self.data_frame.sample(10)

    def clean_columns(self) -> set:
        return set(self.data_frame.columns.str.strip().str.lower())

    def clean_text_data(self, columns: List[str]) -> pd.DataFrame:
        """
        Czyści dane tekstowe w określonych kolumnach DataFrame, zamieniając polskie znaki na ich uniwersalne odpowiedniki
        oraz zachowując spacje między słowami. Konwertuje tekst na małe litery. Pomija wartości numeryczne.

        Args:
        - columns (List[str]): Lista kolumn do oczyszczenia.

        Returns:
        - pd.DataFrame: DataFrame z oczyszczonymi kolumnami.
        """
        
        def clean_text(text):
            if isinstance(text, str):
                text = unicodedata.normalize('NFKD', text)
                text = ''.join([c for c in text if not unicodedata.combining(c)])
                text = text.lower()
                text = ''.join(char if char.isalnum() or char.isspace() else ' ' for char in text)
                return ' '.join(text.split())
            else:
                return text
        
        for column in columns:
            if column in self.data_frame.columns and self.data_frame[column].dtype == object:  # Assumes 'object' dtype for text data
                self.data_frame[column] = self.data_frame[column].apply(clean_text)
        return self.data_frame
    
    def create_nan_column(self, column_names: List[str]):
        for column_name in column_names:
            new_column_name = f"{column_name}_nan"
            self.data_frame[new_column_name] = self.data_frame[column_name].apply(lambda x: 1 if x == 'none' else 0)
        return self.data_frame

    def replace_none_with_binary(self, column_names: List[str]):
        for column_name in column_names:
            self.data_frame[column_name] = self.data_frame[column_name].apply(lambda x: 0 if x in [0, 0.0, 'NONE', 'none', 'nan'] else x)
        return self.data_frame

    def convert_bool_to_int(self, column_names: List[str]) -> pd.DataFrame:
        for column_name in column_names:
            self.data_frame[column_name] = self.data_frame[column_name].apply(lambda x: 1 if x in [True, 'true'] else (0 if x in [False, 'false'] else x))
        return self.data_frame
    
    def convert_column_types(self, column_names, new_type):
        for column_name in column_names:
            try:
                if self.data_frame[column_name].dtype == 'object':
                    self.data_frame[column_name] = self.data_frame[column_name].str.strip().replace(' ', '')
                self.data_frame[column_name] = self.data_frame[column_name].astype(new_type)
            except Exception as e:
                print(f"@ {column_name}': {e}")
        return self.data_frame

    def compare_columns(self, col1: str, col2: str) -> None:
        """
        Compares two columns in the DataFrame, displays rows where the values differ,
        and calculates and displays statistics regarding discrepancies.

        Parameters:
        - col1 (str): Name of the first column to compare.
        - col2 (str): Name of the second column to compare.
        """
        # Remove NONE values and compare columns
        df_no_na = self.data_frame.replace('none', pd.NA).dropna(subset=[col1, col2])
        mismatch = df_no_na[df_no_na[col1] != df_no_na[col2]]

        if mismatch.empty:
            print(f"Columns '{col1}' i '{col2}' are identical.")
        else:
            print(f"### {col1} vs {col2} ###")
            for index, row in mismatch.iterrows():
                print(f"Index: {index}, {col1}: {row[col1]}, {col2}: {row[col2]}")

        #Print raport
        column_verify = self.data_frame[col1] == self.data_frame[col2]
        column_verify.dropna(inplace=True)
        total_count = len(column_verify)
        false_count = (~column_verify).sum()
        false_ratio = false_count / total_count if total_count != 0 else float('inf')
        print(f"Boolen values on each row for CONDITION:{col1} == {col2}: {column_verify}")
        print(f"Ratio of false values in CONDITION: {false_ratio}")

    def complete_none(self) -> None:
        self.data_frame.fillna('none', inplace=True)
        self.data_frame.replace([pd.NA, None, 'nan', 'NaN', '', 'NaN ', 'nan '], 'none', inplace=True)
        self.data_frame = self.data_frame.applymap(lambda x: 'none' if pd.isna(x) else x)

    def delete_columns(self, columns: List[str]) -> None:
        self.data_frame.drop(columns, axis=1, inplace=True)

    def unique_values(self, columns: List[str]) -> None:
        for column in columns:
            if column in self.data_frame.columns:
                unique_values = len(self.data_frame[column].unique())
                none_percentage = (self.data_frame[column] == 'none').mean() * 100
                print(f"UNIQUE VALUES FOR '{column}': {unique_values}")
                print(f"Percentage of 'none' values for '{column}': {none_percentage:.2f}%")
                if unique_values < 6:
                    print(f"Unique values in '{column}': {self.data_frame[column].unique()}")
            else:
                print(f"Column {column} does not exist in DataFrame.")

# %% [markdown]
# # Data loading and analyzing

# %% [markdown]
# ## Morizon

# %%
morizon = PortalData("morizon")

morizon_df = morizon.load_data().copy(deep=True)

morizon.clean_columns()
morizon.complete_none()
morizon.show_dataframe()
# Out:
#                                                     url platform  \
# 2920  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 1200  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 1094  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 2905  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 6618  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 5575  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 6903  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 1025  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 7239  https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
# 910   https://www.morizon.pl/oferta/sprzedaz-mieszka...  morizon
#
#      transaction_type property_type      city             id  total_area  \
# 2920         sprzedaz    mieszkanie  warszawa  mzn2043158237          42
# 1200         sprzedaz    mieszkanie  warszawa  mzn2042982856          81
# 1094         sprzedaz    mieszkanie  warszawa  mzn2043456202          54
# 2905         sprzedaz    mieszkanie  warszawa  mzn2042976359          35
# 6618         sprzedaz    mieszkanie  warszawa  mzn2043483100          61
# 5575         sprzedaz    mieszkanie  warszawa  mzn2043416534          24
# 6903         sprzedaz    mieszkanie  warszawa  mzn2043443824          74
# 1025         sprzedaz    mieszkanie  warszawa  mzn2043220103          58
# 7239         sprzedaz    mieszkanie  warszawa  mzn2043093468          66
# 910          sprzedaz    mieszkanie  warszawa  mzn2043326456          47
#
#             district          prec_adress  row_price  ... material  \
# 2920           ursus    posag 7 panien 16       none  ...     none
# 1200       bialoleka            mankowska       none  ...     none
# 1094       bialoleka                 none    770 000  ...     none
# 2905  praga poludnie  podskarbinska 32 34       none  ...     none
# 6618          bemowo            sternicza    903 000  ...     none
# 5575         mokotow      oskara kolberga    459 000  ...    Cegła
# 6903         ursynow             klobucka  1 379 000  ...     none
# 1025       bialoleka         wlodkowica 9       none  ...     none
# 7239          wlochy     jutrzenki szybka    958 464  ...     none
# 910        bialoleka           marywilska       none  ...     none
#
#                 heating_type                water elevator  gas bath_with_wc  \
# 2920                    none                 none      0.0  0.0          0.0
# 1200                    none                 none      0.0  0.0          0.0
# 1094                    none                 none      1.0  0.0          0.0
# 2905                    none                 none      0.0  0.0          0.0
# 6618  C.O. Z SIECI MIEJSKIEJ                 none      1.0  0.0          0.0
# 5575             Co Miejskie                 Woda      0.0  0.0          0.0
# 6903             Co Miejskie  Woda (Woda miejska)      0.0  0.0          0.0
# 1025                    none                 none      0.0  0.0          0.0
# 7239                    none                 none      0.0  0.0          0.0
# 910                     none                 none      0.0  0.0          0.0
#
#      electricity parking basement balcony
# 2920         0.0     0.0      0.0     0.0
# 1200         0.0     0.0      0.0     0.0
# 1094         0.0     1.0      0.0     0.0
# 2905         0.0     0.0      0.0     0.0
# 6618         0.0     0.0      1.0     0.0
# 5575         0.0     0.0      1.0     0.0
# 6903         0.0     1.0      1.0     1.0
# 1025         0.0     0.0      0.0     1.0
# 7239         0.0     0.0      0.0     0.0
# 910          0.0     0.0      0.0     0.0
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Otodom

# %%
otodom = PortalData("otodom")

otodom_df = otodom.load_data()

otodom.clean_columns()
otodom.complete_none()
otodom.show_dataframe()
# Out:
#             id id_realestateagency                 date_added  \
# 6487  65160433           8016959.0  2024-02-29T10:27:55+01:00
# 1339  65217381           1130589.0  2024-03-14T13:52:47+01:00
# 5991  65149694             89487.0  2024-02-26T19:40:29+01:00
# 6145  65156008           8083484.0  2024-02-28T10:48:36+01:00
# 8194  65106797           3734815.0  2024-02-15T11:52:03+01:00
# 5981  65111867                none  2024-02-16T12:42:21+01:00
# 1519  65096924           1575662.0  2024-02-13T02:35:09+01:00
# 4602  64479129           8184254.0  2023-08-03T09:32:25+02:00
# 8934  64964702           2131948.0  2024-01-08T12:16:37+01:00
# 1958  65214149           9658264.0  2024-03-13T18:30:54+01:00
#
#                     date_update  \
# 6487  2024-03-12T09:16:53+01:00
# 1339  2024-03-15T12:52:00+01:00
# 5991  2024-03-04T21:40:29+01:00
# 6145  2024-03-15T11:40:02+01:00
# 8194  2024-02-19T13:21:47+01:00
# 5981  2024-03-10T06:49:54+01:00
# 1519  2024-03-14T13:39:00+01:00
# 4602  2024-03-12T13:02:23+01:00
# 8934  2024-03-08T12:46:10+01:00
# 1958  2024-03-13T18:30:57+01:00
#
#                                                     url portal_name  \
# 6487  3-pokojowe-mieszkanie-blisko-toru-sluzewiec-ID...      Otodom
# 1339  swietnie-skomunikowane-duzy-balkon-majdanska-I...      Otodom
# 5991  metro-ksiecia-janusza-trzy-pokoje-z-balkonem-I...      Otodom
# 6145  3-pokojowe-mieszkanie-62m2-2-loggie-bezposredn...      Otodom
# 8194  grzybowska-4-apartament-na-biuro-na-sprzedaz-I...      Otodom
# 5981     warszawa-bemowo-widawska-60m2-3-pokoje-ID4pczp      Otodom
# 1519     apartament-137-2-4-pokoje-okopowa-wola-ID4p8Go      Otodom
# 4602  3-pokojowy-loft-73m2-loggia-bez-posrednikow-ID...      Otodom
# 8934       dwupoziomowy-apartament-na-mokotowie-ID4oAhM      Otodom
# 1958       oferta-dwustronne-3-pokoje-pierwotny-ID4pDb7      Otodom
#
#      market_type property_type      price row_price_m2  ...  \
# 6487   SECONDARY    mieszkanie  1050000.0      16154.0  ...
# 1339   SECONDARY    mieszkanie   749000.0      14404.0  ...
# 5991   SECONDARY    mieszkanie   689000.0      14035.0  ...
# 6145     PRIMARY    mieszkanie   986236.0      15800.0  ...
# 8194   SECONDARY    mieszkanie  4500000.0      33259.0  ...
# 5981   SECONDARY    mieszkanie   829000.0      13817.0  ...
# 1519   SECONDARY    mieszkanie  2595000.0      18914.0  ...
# 4602     PRIMARY    mieszkanie       none         none  ...
# 8934   SECONDARY    mieszkanie  3400000.0      33010.0  ...
# 1958     PRIMARY    mieszkanie   770000.0      14808.0  ...
#
#                material heating_type elevator heating_type.1  windows  \
# 6487               none         none      1.0           none  plastic
# 1339     concrete_plate        urban      1.0          urban     none
# 5991               none         none      1.0           none  plastic
# 6145               none         none      1.0           none     none
# 8194               none         none      1.0           none     none
# 5981              other        urban      1.0          urban  plastic
# 1519  cellular_concrete         none      1.0           none     none
# 4602               none         none      1.0           none     none
# 8934               none        urban      1.0          urban     none
# 1958  cellular_concrete        urban      1.0          urban  plastic
#
#       balcony/loggia parking_type  basement  \
# 6487             1.0       garage      none
# 1339             1.0         none      none
# 5991             1.0         none  basement
# 6145             1.0       garage      none
# 8194             1.0       garage      none
# 5981             1.0         none  basement
# 1519             1.0       garage      none
# 4602             1.0       garage      none
# 8934             1.0       garage      none
# 1958             1.0       garage      none
#
#                                                security property_rent
# 6487        ['closed_area', 'entryphone', 'monitoring']          none
# 1339                                               none          none
# 5991                                               none          none
# 6145                                               none          none
# 8194                                               none        1300.0
# 5981  ['anti_burglary_door', 'entryphone', 'monitori...         760.0
# 1519                                               none        1800.0
# 4602                                    ['closed_area']          none
# 8934                                     ['monitoring']        2800.0
# 1958               ['anti_burglary_door', 'entryphone']          none
#
# [10 rows x 33 columns]

# %% [markdown]
# ### Verification of corresponding columns (with the same name, suffix .1 given by Pandas).

# %% [markdown]
# #### district vs district.1

# %%
otodom.compare_columns("district", "district.1")
# Out:
# Columns 'district' i 'district.1' are identical.
# Boolen values on each row for CONDITION:district == district.1: 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 11337    True
# 11338    True
# 11339    True
# 11340    True
# 11341    True
# Length: 11342, dtype: bool
# Ratio of false values in CONDITION: 0.0

# %% [markdown]
# #### heating_type vs heating_type.1

# %%
otodom.compare_columns("heating_type", 'heating_type.1')
# Out:
# Columns 'heating_type' i 'heating_type.1' are identical.
# Boolen values on each row for CONDITION:heating_type == heating_type.1: 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 11337    True
# 11338    True
# 11339    True
# 11340    True
# 11341    True
# Length: 11342, dtype: bool
# Ratio of false values in CONDITION: 0.0

# %% [markdown]
# #### street vs street.1

# %%
otodom.compare_columns("street", 'street.1')
# Out:
# Columns 'street' i 'street.1' are identical.
# Boolen values on each row for CONDITION:street == street.1: 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 11337    True
# 11338    True
# 11339    True
# 11340    True
# 11341    True
# Length: 11342, dtype: bool
# Ratio of false values in CONDITION: 0.0

# %% [markdown]
# ##### Removing unnecessary (duplicate) columns from otodom:
#     - street.1
#     - heating_type.1
#     - district.1

# %%
duplicated_columns = ['street.1', 'heating_type.1', 'district.1']
otodom.delete_columns(duplicated_columns)

#Check
for column in duplicated_columns: 
    print(column in otodom.df.columns)
# Out:
# False
# False
# False

# %% [markdown]
# ## Nieruchomosci Online

# %%
no = PortalData("no")
no_df = no.load_data().copy(deep=True)

no.clean_columns()
no.complete_none()
no.show_dataframe()
# Out:
#      balcony/loggia basement  \
# 5944           True    False
# 5299          False    False
# 212            True    False
# 3028          False     True
# 5974           True    False
# 6486           True    False
# 2640           True     True
# 2185           True    False
# 170            True    False
# 1703           True    False
#
#                                            bulding_type bulding_year  \
# 5944                                    blok mieszkalny         2010
# 5299                                    apartamentowiec         2019
# 212                                     blok mieszkalny         2002
# 3028                                    blok mieszkalny         1962
# 5974                                    apartamentowiec         2022
# 6486                                    apartamentowiec         2017
# 2640  rok budowy: 2001, technika budowy: tradycyjna/...         2001
# 2185                                    apartamentowiec         2018
# 170                                     apartamentowiec         2017
# 1703  rok budowy: 2023 (blok w nowym budownictwie), ...         2023
#
#      date_added date_update        district  electricity  elevator   gas  ...  \
# 5944       none  20.02.2024         Centrum         True     False  none  ...
# 5299       none  14.03.2024            Wola         True      True  none  ...
# 212        none  18.03.2024         Ursynów         True      True  none  ...
# 3028       none  14.03.2024            Wola         True      True  none  ...
# 5974       none  27.01.2024         Ursynów         True      True  none  ...
# 6486       none  26.02.2024  Praga-Południe         True     False  none  ...
# 2640       none  10.01.2024        Żoliborz         True      True  none  ...
# 2185       none  30.01.2024          Ochota         True      True  none  ...
# 170        none  18.03.2024           Ursus         True      True  none  ...
# 1703       none  08.11.2023        Gocławek         True      True  none  ...
#
#      saperate_wc                                           security  \
# 5944         1.0                      drzwi antywłamaniowe, ochrona
# 5299         1.0  domofon/wideofon, drzwi antywłamaniowe, monito...
# 212          1.0                                   domofon/wideofon
# 3028         1.0                                               none
# 5974        none  drzwi antywłamaniowe, domofon/wideofon, monito...
# 6486        none                                               none
# 2640         2.0  alarm, domofon/wideofon, monitoring/kamery, oc...
# 2185         1.0                                               none
# 170         none                            alarm, domofon/wideofon
# 1703         1.0                                               none
#
#              standard               street total_area total_property_level  \
# 5944     bardzo dobry                Bagno      69.15                 14.0
# 5299     bardzo dobry            Karolkowa      55.00                  8.0
# 212             dobry             Lanciego      69.00                 10.0
# 3028            dobry             Chmielna      27.00                 10.0
# 5974     deweloperski               Kraski      37.00                  4.0
# 6486             none       Rodziewiczówny      98.00                 25.0
# 2640  wysoki standard             Zajączka     144.85                  5.0
# 2185  wysoki standard  Aleje Jerozolimskie      29.00                  4.0
# 170             dobry              Hennela      59.00                  6.0
# 1703             none             Szaserów      75.02                  4.0
#
#      town/city                                                url water  \
# 5944  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 5299  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 212   Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 3028  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 5974  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 6486  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 2640  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 2185  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 170   Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
# 1703  Warszawa  https://warszawa.nieruchomosci-online.pl/miesz...  True
#
#                 windows
# 5944  nowe / wymienione
# 5299  nowe / wymienione
# 212                none
# 3028         plastikowe
# 5974               none
# 6486  nowe / wymienione
# 2640  nowe / wymienione
# 2185               none
# 170                none
# 1703               none
#
# [10 rows x 38 columns]

# %%
no.compare_columns("no_parking_space", 'parking_type')
# Out:
# ### no_parking_space vs parking_type ###
# Index: 0, no_parking_space: 1, parking_type: garaż
# Index: 1, no_parking_space: 1, parking_type: garaż
# Index: 4, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 5, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 7, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 8, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 9, no_parking_space: 1, parking_type: garaż
# Index: 10, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 12, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 13, no_parking_space: 1, parking_type: tak
# Index: 14, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 16, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 18, no_parking_space: 1, parking_type: garaż (2 miejsca parkingowe)
# Index: 19, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 20, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 21, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 22, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 23, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 24, no_parking_space: 1, parking_type: garaż
# Index: 25, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 27, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 29, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 32, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 33, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 34, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 35, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 37, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 38, no_parking_space: 1, parking_type: garaż
# Index: 39, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 40, no_parking_space: 1, parking_type: garaż
# Index: 42, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 43, no_parking_space: 1, parking_type: garaż
# Index: 44, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 45, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 46, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (2 miejsca parkingowe)
# Index: 47, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 48, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 49, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 50, no_parking_space: 1, parking_type: garaż
# Index: 51, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 52, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 53, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 54, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 55, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 56, no_parking_space: 1, parking_type: garaż
# Index: 57, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 58, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 59, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 60, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 61, no_parking_space: 1, parking_type: przynależne na ulicy (2 miejsca parkingowe)
# Index: 63, no_parking_space: 1, parking_type: garaż w bryle budynku (1 miejsce parkingowe)
# Index: 64, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 65, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 66, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 67, no_parking_space: 1, parking_type: tak
# Index: 68, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 69, no_parking_space: 1, parking_type: garaż
# Index: 70, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 71, no_parking_space: 1, parking_type: przynależne na ulicy (2 miejsca parkingowe)
# Index: 72, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 75, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 76, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 77, no_parking_space: 1, parking_type: garaż
# Index: 78, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 79, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 81, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 82, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 83, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 85, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 86, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 87, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 88, no_parking_space: 1, parking_type: garaż
# Index: 89, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 90, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 91, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 92, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 93, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 94, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 95, no_parking_space: 1, parking_type: tak
# Index: 96, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 97, no_parking_space: 1, parking_type: garaż w bryle budynku (1 miejsce parkingowe)
# Index: 98, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 99, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 100, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 101, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 102, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 103, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 104, no_parking_space: 1, parking_type: tak
# Index: 105, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 106, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 107, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 108, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 109, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 110, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 111, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 112, no_parking_space: 1, parking_type: garaż
# Index: 115, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 116, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 117, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 118, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 119, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 120, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 121, no_parking_space: 1, parking_type: garaż
# Index: 122, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 123, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 126, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 127, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 128, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 130, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 131, no_parking_space: 1, parking_type: tak
# Index: 133, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 134, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 136, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 142, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 143, no_parking_space: 1, parking_type: tak
# Index: 144, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 146, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 147, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 149, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 151, no_parking_space: 1, parking_type: garaż
# Index: 152, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 153, no_parking_space: 1, parking_type: garaż
# Index: 154, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 156, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 158, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 160, no_parking_space: 2, parking_type: możliwość wykupienia, parking publiczny / na ulicy
# Index: 161, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 163, no_parking_space: 1, parking_type: tak
# Index: 164, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 165, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 167, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 170, no_parking_space: 1, parking_type: garaż
# Index: 171, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 174, no_parking_space: 1, parking_type: garaż
# Index: 175, no_parking_space: 1, parking_type: garaż
# Index: 176, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 177, no_parking_space: 1, parking_type: tak
# Index: 178, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 182, no_parking_space: 1, parking_type: tak
# Index: 183, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 184, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 185, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 186, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 187, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 188, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 189, no_parking_space: 1, parking_type: tak
# Index: 190, no_parking_space: 1, parking_type: tak
# Index: 191, no_parking_space: 1, parking_type: garaż
# Index: 192, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 193, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 194, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 195, no_parking_space: 1, parking_type: garaż
# Index: 196, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 198, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 199, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 200, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 201, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 202, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 203, no_parking_space: 1, parking_type: możliwość wykupienia
# Index: 204, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 205, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 206, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 207, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 211, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 212, no_parking_space: 1, parking_type: garaż
# Index: 213, no_parking_space: 1, parking_type: tak
# Index: 214, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 216, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (70 miejsc parkingowych)
# Index: 219, no_parking_space: 1, parking_type: garaż
# Index: 220, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 221, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 222, no_parking_space: 1, parking_type: garaż
# Index: 223, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 224, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 227, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 228, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 229, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 231, no_parking_space: 1, parking_type: tak
# Index: 232, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 233, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 234, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 235, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 236, no_parking_space: 1, parking_type: garaż
# Index: 238, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 239, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym
# Index: 240, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 242, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 243, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 244, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 246, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 247, no_parking_space: 1, parking_type: garaż
# Index: 248, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 249, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 250, no_parking_space: 1, parking_type: garaż wolnostojący (2 miejsca parkingowe)
# Index: 252, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 253, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 254, no_parking_space: 1, parking_type: tak
# Index: 255, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 256, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 257, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 259, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym
# Index: 260, no_parking_space: 1, parking_type: garaż
# Index: 261, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 262, no_parking_space: 1, parking_type: garaż
# Index: 263, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 264, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 266, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 267, no_parking_space: 1, parking_type: garaż
# Index: 271, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 273, no_parking_space: 1, parking_type: garaż
# Index: 278, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 279, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 280, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 282, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 283, no_parking_space: 1, parking_type: garaż
# Index: 284, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 285, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 287, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 288, no_parking_space: 1, parking_type: tak
# Index: 289, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 291, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 292, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 293, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 294, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 295, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 296, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 297, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 298, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 300, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 302, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 303, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 304, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 306, no_parking_space: 1, parking_type: garaż
# Index: 307, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 308, no_parking_space: 1, parking_type: tak
# Index: 309, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 310, no_parking_space: 1, parking_type: garaż
# Index: 311, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 312, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 313, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 314, no_parking_space: 1, parking_type: tak
# Index: 315, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 316, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 317, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 318, no_parking_space: 1, parking_type: garaż
# Index: 320, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 321, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 322, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 323, no_parking_space: 1, parking_type: tak
# Index: 326, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 329, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 330, no_parking_space: 1, parking_type: tak
# Index: 331, no_parking_space: 1, parking_type: garaż
# Index: 332, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 333, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 336, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 337, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 338, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 340, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 341, no_parking_space: 1, parking_type: garaż (2 miejsca parkingowe)
# Index: 342, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 344, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 345, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 346, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 347, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 348, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 349, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 350, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym
# Index: 351, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 354, no_parking_space: 1, parking_type: garaż
# Index: 355, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 356, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 357, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 359, no_parking_space: 1, parking_type: tak
# Index: 360, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 361, no_parking_space: 1, parking_type: tak
# Index: 362, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 364, no_parking_space: 1, parking_type: garaż
# Index: 365, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 366, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 367, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 368, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym
# Index: 370, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 371, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 373, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 374, no_parking_space: 1, parking_type: tak
# Index: 375, no_parking_space: 1, parking_type: garaż
# Index: 376, no_parking_space: 1, parking_type: garaż
# Index: 377, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 378, no_parking_space: 1, parking_type: garaż
# Index: 379, no_parking_space: 1, parking_type: garaż
# Index: 380, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 382, no_parking_space: 1, parking_type: tak
# Index: 385, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 386, no_parking_space: 1, parking_type: garaż
# Index: 388, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 389, no_parking_space: 1, parking_type: garaż
# Index: 390, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 391, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 393, no_parking_space: 1, parking_type: garaż
# Index: 394, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 396, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 397, no_parking_space: 1, parking_type: garaż
# Index: 398, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 400, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 401, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 402, no_parking_space: 1, parking_type: garaż
# Index: 403, no_parking_space: 1, parking_type: garaż
# Index: 404, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 405, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 406, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 409, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 410, no_parking_space: 1, parking_type: garaż
# Index: 411, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 412, no_parking_space: 1, parking_type: garaż
# Index: 413, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 416, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 418, no_parking_space: 1, parking_type: garaż
# Index: 419, no_parking_space: 1, parking_type: garaż wolnostojący (2 miejsca parkingowe)
# Index: 421, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 422, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 424, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 425, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 426, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 427, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 429, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 430, no_parking_space: 1, parking_type: garaż
# Index: 431, no_parking_space: 1, parking_type: garaż
# Index: 433, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 434, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 435, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 437, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 438, no_parking_space: 1, parking_type: garaż
# Index: 439, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 440, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 441, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 442, no_parking_space: 1, parking_type: garaż
# Index: 443, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 444, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 446, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 448, no_parking_space: 1, parking_type: garaż
# Index: 449, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 450, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 451, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 452, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 454, no_parking_space: 1, parking_type: garaż
# Index: 455, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 456, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 457, no_parking_space: 1, parking_type: tak
# Index: 458, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 460, no_parking_space: 1, parking_type: garaż
# Index: 461, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 462, no_parking_space: 1, parking_type: garaż
# Index: 464, no_parking_space: 1, parking_type: garaż
# Index: 468, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 470, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 471, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 472, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 473, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 475, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 476, no_parking_space: 1, parking_type: tak
# Index: 479, no_parking_space: 1, parking_type: garaż
# Index: 480, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 481, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 485, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 486, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 487, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 488, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 489, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 490, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 492, no_parking_space: 1, parking_type: garaż
# Index: 495, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 497, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 499, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 500, no_parking_space: 1, parking_type: garaż
# Index: 501, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 502, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 503, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 505, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 506, no_parking_space: 1, parking_type: garaż
# Index: 507, no_parking_space: 1, parking_type: garaż
# Index: 509, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 510, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 512, no_parking_space: 1, parking_type: tak
# Index: 514, no_parking_space: 1, parking_type: garaż
# Index: 515, no_parking_space: 1, parking_type: garaż
# Index: 516, no_parking_space: 1, parking_type: tak
# Index: 517, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 518, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 521, no_parking_space: 1, parking_type: garaż
# Index: 523, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 524, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 526, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 527, no_parking_space: 1, parking_type: garaż
# Index: 528, no_parking_space: 1, parking_type: garaż wolnostojący (4 miejsca parkingowe)
# Index: 530, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 531, no_parking_space: 1, parking_type: garaż
# Index: 532, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 534, no_parking_space: 1, parking_type: tak
# Index: 535, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 536, no_parking_space: 1, parking_type: tak
# Index: 538, no_parking_space: 1, parking_type: przynależne na ulicy (2 miejsca parkingowe)
# Index: 539, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 541, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 543, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 546, no_parking_space: 1, parking_type: tak
# Index: 547, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 548, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 549, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 552, no_parking_space: 1, parking_type: garaż
# Index: 553, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 554, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 556, no_parking_space: 1, parking_type: garaż
# Index: 557, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 558, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 559, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 561, no_parking_space: 1, parking_type: garaż
# Index: 562, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 563, no_parking_space: 2, parking_type: możliwość wykupienia, parking strzeżony w pobliżu
# Index: 564, no_parking_space: 1, parking_type: tak
# Index: 565, no_parking_space: 1, parking_type: garaż
# Index: 566, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 567, no_parking_space: 1, parking_type: tak
# Index: 568, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 569, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 570, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 571, no_parking_space: 1, parking_type: garaż
# Index: 572, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 573, no_parking_space: 1, parking_type: garaż
# Index: 574, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 575, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 576, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 578, no_parking_space: 1, parking_type: garaż
# Index: 579, no_parking_space: 1, parking_type: tak
# Index: 580, no_parking_space: 1, parking_type: garaż
# Index: 582, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 586, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 587, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 589, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 590, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 591, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 592, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 593, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 594, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 595, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 597, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 598, no_parking_space: 1, parking_type: tak
# Index: 599, no_parking_space: 1, parking_type: garaż
# Index: 600, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 603, no_parking_space: 1, parking_type: garaż wolnostojący (2 miejsca parkingowe)
# Index: 604, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 605, no_parking_space: 1, parking_type: garaż wolnostojący (2 miejsca parkingowe)
# Index: 607, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 608, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 609, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 610, no_parking_space: 1, parking_type: tak
# Index: 611, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 612, no_parking_space: 1, parking_type: przynależne na ulicy (2 miejsca parkingowe)
# Index: 613, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 614, no_parking_space: 1, parking_type: tak
# Index: 615, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 616, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 618, no_parking_space: 1, parking_type: garaż
# Index: 621, no_parking_space: 1, parking_type: garaż
# Index: 623, no_parking_space: 1, parking_type: garaż
# Index: 624, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 625, no_parking_space: 1, parking_type: tak
# Index: 627, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym
# Index: 628, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 629, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 631, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 633, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 634, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 635, no_parking_space: 1, parking_type: tak
# Index: 636, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 637, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 638, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 639, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 640, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 643, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 644, no_parking_space: 1, parking_type: garaż
# Index: 646, no_parking_space: 1, parking_type: garaż
# Index: 648, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 649, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 650, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 652, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 655, no_parking_space: 1, parking_type: garaż
# Index: 656, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 658, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 659, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 660, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 661, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 662, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 663, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 664, no_parking_space: 1, parking_type: garaż
# Index: 665, no_parking_space: 1, parking_type: garaż
# Index: 667, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 668, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 670, no_parking_space: 1, parking_type: garaż
# Index: 671, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 672, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 673, no_parking_space: 2, parking_type: możliwość wykupienia, parking publiczny / na ulicy
# Index: 675, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 676, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 678, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 681, no_parking_space: 1, parking_type: garaż
# Index: 682, no_parking_space: 1, parking_type: przynależne na ulicy (2 miejsca parkingowe)
# Index: 683, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 689, no_parking_space: 1, parking_type: garaż
# Index: 690, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 692, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 693, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 694, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 695, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 696, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 697, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 698, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 699, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 700, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 701, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 702, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 706, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 708, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 709, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 710, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 711, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 713, no_parking_space: 1, parking_type: tak
# Index: 714, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 716, no_parking_space: 1, parking_type: tak
# Index: 718, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 719, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 720, no_parking_space: 1, parking_type: garaż
# Index: 721, no_parking_space: 1, parking_type: garaż
# Index: 722, no_parking_space: 1, parking_type: garaż
# Index: 723, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 724, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 725, no_parking_space: 1, parking_type: garaż
# Index: 727, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 728, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 730, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 731, no_parking_space: 1, parking_type: tak
# Index: 732, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 733, no_parking_space: 1, parking_type: tak
# Index: 734, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 735, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 736, no_parking_space: 1, parking_type: garaż
# Index: 737, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 738, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 740, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 741, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 742, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 743, no_parking_space: 1, parking_type: garaż
# Index: 746, no_parking_space: 1, parking_type: tak
# Index: 748, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 749, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 751, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 752, no_parking_space: 1, parking_type: tak
# Index: 753, no_parking_space: 1, parking_type: garaż
# Index: 754, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 755, no_parking_space: 1, parking_type: tak
# Index: 756, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 757, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 758, no_parking_space: 1, parking_type: tak
# Index: 759, no_parking_space: 1, parking_type: tak
# Index: 760, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 761, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 762, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 763, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 764, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 766, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 767, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 769, no_parking_space: 1, parking_type: garaż
# Index: 770, no_parking_space: 1, parking_type: tak
# Index: 771, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 774, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 776, no_parking_space: 1, parking_type: tak
# Index: 778, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 779, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 780, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 782, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 783, no_parking_space: 1, parking_type: tak
# Index: 784, no_parking_space: 1, parking_type: tak
# Index: 785, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 786, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 787, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 788, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 790, no_parking_space: 1, parking_type: tak
# Index: 792, no_parking_space: 1, parking_type: garaż
# Index: 793, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 795, no_parking_space: 1, parking_type: garaż
# Index: 797, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 798, no_parking_space: 1, parking_type: przynależne na ulicy
# Index: 799, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 800, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 801, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 802, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 803, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 805, no_parking_space: 1, parking_type: tak
# Index: 806, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 809, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 814, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 815, no_parking_space: 1, parking_type: garaż
# Index: 816, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 817, no_parking_space: 1, parking_type: garaż
# Index: 819, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 821, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 823, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 825, no_parking_space: 1, parking_type: tak
# Index: 826, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 829, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 831, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 832, no_parking_space: 1, parking_type: garaż
# Index: 834, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 835, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 836, no_parking_space: 1, parking_type: garaż
# Index: 839, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 843, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 844, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 845, no_parking_space: 1, parking_type: garaż
# Index: 846, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 847, no_parking_space: 1, parking_type: garaż w bryle budynku
# ...
# Index: 6737, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6739, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6740, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 6741, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6743, no_parking_space: 1, parking_type: garaż
# Index: 6744, no_parking_space: 1, parking_type: garaż
# Index: 6745, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6746, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6747, no_parking_space: 1, parking_type: przynależne na ulicy (2 miejsca parkingowe)
# Index: 6748, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6749, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6750, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym
# Index: 6751, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6753, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6754, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6755, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6756, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6757, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6759, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6763, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6764, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6765, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6766, no_parking_space: 1, parking_type: garaż w bryle budynku
# Index: 6767, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6768, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6769, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6770, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6772, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6773, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6774, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6776, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6778, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6779, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6780, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6781, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6782, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6783, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6785, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6786, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6787, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6789, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6792, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6796, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6798, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6799, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6800, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6802, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6804, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6805, no_parking_space: 1, parking_type: garaż
# Index: 6806, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6807, no_parking_space: 1, parking_type: tak
# Index: 6808, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6809, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6810, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6812, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6813, no_parking_space: 1, parking_type: garaż
# Index: 6814, no_parking_space: 1, parking_type: tak
# Index: 6815, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6816, no_parking_space: 1, parking_type: tak
# Index: 6818, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6819, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6821, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6823, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6824, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6825, no_parking_space: 1, parking_type: garaż
# Index: 6826, no_parking_space: 1, parking_type: tak
# Index: 6828, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6829, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6830, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6831, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6832, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6833, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6835, no_parking_space: 1, parking_type: tak
# Index: 6836, no_parking_space: 1, parking_type: możliwość wykupienia
# Index: 6840, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6842, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6843, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6844, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6845, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6846, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6847, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6848, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6851, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6853, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6854, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 6855, no_parking_space: 1, parking_type: garaż
# Index: 6856, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6860, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6861, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6862, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6863, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6865, no_parking_space: 1, parking_type: możliwość wykupienia
# Index: 6866, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6867, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6869, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6870, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6874, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6876, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6877, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6878, no_parking_space: 1, parking_type: tak
# Index: 6880, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6881, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6884, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6886, no_parking_space: 1, parking_type: tak
# Index: 6889, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6891, no_parking_space: 1, parking_type: tak
# Index: 6892, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6893, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6895, no_parking_space: 1, parking_type: tak
# Index: 6896, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6897, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6898, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6899, no_parking_space: 1, parking_type: tak
# Index: 6900, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6901, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6902, no_parking_space: 1, parking_type: garaż
# Index: 6903, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6904, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6905, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6906, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6907, no_parking_space: 1, parking_type: tak
# Index: 6908, no_parking_space: 1, parking_type: garaż wolnostojący (2 miejsca parkingowe)
# Index: 6909, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6910, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6911, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6912, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6913, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6914, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6916, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 6918, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6921, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6922, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 6923, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6924, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6925, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6928, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6929, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6930, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6931, no_parking_space: 1, parking_type: przynależne na ulicy (360 miejsc parkingowych)
# Index: 6934, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6935, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6936, no_parking_space: 1, parking_type: garaż
# Index: 6937, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6938, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6939, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6941, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6942, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6943, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6944, no_parking_space: 1, parking_type: garaż wolnostojący (2 miejsca parkingowe)
# Index: 6945, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6946, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6947, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6948, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6949, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6950, no_parking_space: 1, parking_type: przynależne na terenie ogrodzonym (1 miejsce parkingowe)
# Index: 6951, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6953, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6954, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6957, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6958, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6959, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6961, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6962, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 6963, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 6964, no_parking_space: 1, parking_type: w garażu podziemnym (2 miejsca parkingowe)
# Index: 6965, no_parking_space: 1, parking_type: garaż
# Index: 6967, no_parking_space: 1, parking_type: tak
# Index: 6970, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6971, no_parking_space: 1, parking_type: przynależne na ulicy (1 miejsce parkingowe)
# Index: 6973, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6975, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 6976, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 6978, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 6981, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 7005, no_parking_space: 1, parking_type: garaż
# Index: 7008, no_parking_space: 1, parking_type: parking strzeżony w pobliżu
# Index: 7009, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 7010, no_parking_space: 1, parking_type: garaż wolnostojący (1 miejsce parkingowe)
# Index: 7011, no_parking_space: 2, parking_type: parking strzeżony w pobliżu, parking publiczny / na ulicy
# Index: 7013, no_parking_space: 1, parking_type: garaż
# Index: 7015, no_parking_space: 1, parking_type: tak
# Index: 7018, no_parking_space: 1, parking_type: tak
# Index: 7020, no_parking_space: 1, parking_type: parking publiczny / na ulicy
# Index: 7022, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 7023, no_parking_space: 1, parking_type: garaż
# Index: 7024, no_parking_space: 1, parking_type: garaż
# Index: 7025, no_parking_space: 1, parking_type: tak
# Index: 7027, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 7028, no_parking_space: 1, parking_type: w garażu podziemnym (1 miejsce parkingowe)
# Index: 7030, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 7036, no_parking_space: 1, parking_type: brak przynależnego miejsca parkingowego
# Index: 7037, no_parking_space: 1, parking_type: w garażu podziemnym
# Index: 7038, no_parking_space: 1, parking_type: garaż
# Index: 7040, no_parking_space: 1, parking_type: tak
# Boolen values on each row for CONDITION:no_parking_space == parking_type: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7037    False
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# Length: 7042, dtype: bool
# Ratio of false values in CONDITION: 1.0

# %% [markdown]
# ## Define colections for objects

# %%
portal_data_objects = [morizon, otodom, no]

objects_dataframes = {
    'morizon': morizon.df,
    'otodom': otodom.df,
    'no': no.df
}

# %% [markdown]
# ## Proces parking columns in all PortalData instances
# Goal:
# - Create column <b>is_parking</b> as [1,0] values if we have information
# - Create column <b> parkin_na</b> as [1,0] values, if information was not given (referenced to OtoDom data structure)
# - Drop curent columns with parking informations

# %% [markdown]
# ### N-O

# %%
no.df.columns
# Out:
# Index(['balcony/loggia', 'basement', 'bulding_type', 'bulding_year',
#        'date_added', 'date_update', 'district', 'electricity', 'elevator',
#        'gas', 'heating_type', 'height', 'id_portal', 'id_realestateagency',
#        'kitchen_type', 'makret_type', 'material', 'no_parking_space',
#        'no_rooms', 'ownership_form', 'parking_type', 'portal_name',
#        'prec_adress', 'price', 'property_level', 'property_rent',
#        'property_type', 'row_price_m2', 'saperate_wc', 'security', 'standard',
#        'street', 'total_area', 'total_property_level', 'town/city', 'url',
#        'water', 'windows'],
#       dtype='object')

# %%
no.unique_values(['parking_type', 'no_parking_space'])
# Out:
# UNIQUE VALUES FOR 'parking_type': 41
# Percentage of 'none' values for 'parking_type': 26.29%
# UNIQUE VALUES FOR 'no_parking_space': 4
# Percentage of 'none' values for 'no_parking_space': 0.00%
# Unique values in 'no_parking_space': [1 0 2 3]

# %%
no_parking_unique = no.df['parking_type'].unique()
print(no_parking_unique)
len(no_parking_unique)
# Out:
# ['garaż' 'none' 'w garażu podziemnym (2 miejsca parkingowe)'
#  'brak przynależnego miejsca parkingowego'
#  'przynależne na ulicy (1 miejsce parkingowe)'
#  'garaż wolnostojący (1 miejsce parkingowe)' 'tak'
#  'garaż (2 miejsca parkingowe)'
#  'w garażu podziemnym (1 miejsce parkingowe)' 'w garażu podziemnym'
#  'przynależne na terenie ogrodzonym (1 miejsce parkingowe)'
#  'parking publiczny / na ulicy'
#  'przynależne na terenie ogrodzonym (2 miejsca parkingowe)'
#  'parking strzeżony w pobliżu, parking publiczny / na ulicy'
#  'parking strzeżony w pobliżu'
#  'przynależne na ulicy (2 miejsca parkingowe)'
#  'garaż w bryle budynku (1 miejsce parkingowe)' 'garaż w bryle budynku'
#  'możliwość wykupienia, parking publiczny / na ulicy'
#  'przynależne na ulicy' 'możliwość wykupienia'
#  'przynależne na terenie ogrodzonym (70 miejsc parkingowych)'
#  'przynależne na terenie ogrodzonym'
#  'garaż wolnostojący (2 miejsca parkingowe)'
#  'garaż wolnostojący (4 miejsca parkingowe)'
#  'możliwość wykupienia, parking strzeżony w pobliżu'
#  'tak (1 miejsce parkingowe)'
#  'możliwość wykupienia, parking strzeżony w pobliżu, parking publiczny / na ulicy'
#  'przynależne na ulicy (3 miejsca parkingowe)'
#  'w garażu podziemnym (4 miejsca parkingowe)'
#  'w garażu podziemnym (3 miejsca parkingowe)'
#  'tak (5 miejsc parkingowych)' 'garaż wolnostojący'
#  'garaż w bryle budynku (2 miejsca parkingowe)'
#  'przynależne na ulicy (10 miejsc parkingowych)'
#  'w garażu podziemnym (14 miejsc parkingowych)'
#  'w garażu podziemnym (11 miejsc parkingowych)'
#  'w garażu podziemnym (60 miejsc parkingowych)'
#  'tak (2 miejsca parkingowe)'
#  'w garażu podziemnym (8 miejsc parkingowych)'
#  'przynależne na ulicy (360 miejsc parkingowych)']
# 41

# %%
#this values gives us information to correct informations given in no_parking_space. 
# If value given, real estate have not law to any parking space or it's additional cost
no_parking_not_own = [
    'brak przynależnego miejsca parkingowego',
    'parking publiczny / na ulicy',
    'możliwość wykupienia',
    'parking strzeżony w pobliżu',
]

no_parking_df = no.df[['parking_type', 'no_parking_space']]

#colect one hot encoding vie of law to parking space with NONEs
no_parking_df['parking_own'] = no_parking_df['parking_type'].apply(
    lambda x: 'none' if x == 'NONE' 
    else (0 
    if any(parking_option in no_parking_not_own for parking_option in str(x).split(',')) 
    else 1)
)
no_parking_df.sample(20)
# Out:
# /var/folders/sh/pxc94xyx7jx4j8wws1vh_np80000gn/T/ipykernel_72353/2730438520.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_parking_df['parking_own'] = no_parking_df['parking_type'].apply(
#                                     parking_type  no_parking_space  \
# 6180     brak przynależnego miejsca parkingowego                 1
# 4887                                        none                 0
# 585                                         none                 0
# 5862                                         tak                 1
# 4078     brak przynależnego miejsca parkingowego                 1
# 3069                                        none                 0
# 4549     brak przynależnego miejsca parkingowego                 1
# 674                                         none                 0
# 3902  w garażu podziemnym (1 miejsce parkingowe)                 1
# 6822                                        none                 0
# 2250                                        none                 0
# 700    garaż wolnostojący (1 miejsce parkingowe)                 1
# 6292                                        none                 0
# 1164     brak przynależnego miejsca parkingowego                 1
# 143                                          tak                 1
# 4942     brak przynależnego miejsca parkingowego                 1
# 3383                                        none                 0
# 2854  w garażu podziemnym (2 miejsca parkingowe)                 1
# 4828  w garażu podziemnym (1 miejsce parkingowe)                 1
# 5348                                       garaż                 1
#
#       parking_own
# 6180            0
# 4887            1
# 585             1
# 5862            1
# 4078            0
# 3069            1
# 4549            0
# 674             1
# 3902            1
# 6822            1
# 2250            1
# 700             1
# 6292            1
# 1164            0
# 143             1
# 4942            0
# 3383            1
# 2854            1
# 4828            1
# 5348            1

# %%
no_parking_df.loc[no_parking_df['parking_own'] == 1, 'no_parking_space'] = 1
#colect informations about NONEs to one hot encoding structure
no_parking_df['parking_nan'] = no_parking_df['parking_type'].apply(lambda x: 1 if x == 'none' else 0)
no_parking_df.sample(20)
# Out:
# /var/folders/sh/pxc94xyx7jx4j8wws1vh_np80000gn/T/ipykernel_72353/1364810480.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_parking_df['parking_nan'] = no_parking_df['parking_type'].apply(lambda x: 1 if x == 'none' else 0)
#                                      parking_type  no_parking_space  \
# 5937   w garażu podziemnym (1 miejsce parkingowe)                 1
# 5238      brak przynależnego miejsca parkingowego                 1
# 6558   w garażu podziemnym (1 miejsce parkingowe)                 1
# 4287                                         none                 1
# 4169                                          tak                 1
# 2696                                          tak                 1
# 3141    garaż wolnostojący (1 miejsce parkingowe)                 1
# 3170                                         none                 1
# 6831   w garażu podziemnym (1 miejsce parkingowe)                 1
# 606                                          none                 1
# 6575                 parking publiczny / na ulicy                 1
# 1026  przynależne na ulicy (1 miejsce parkingowe)                 1
# 2708                                         none                 1
# 1786    garaż wolnostojący (1 miejsce parkingowe)                 1
# 317    w garażu podziemnym (1 miejsce parkingowe)                 1
# 1599                        garaż w bryle budynku                 1
# 6303   w garażu podziemnym (1 miejsce parkingowe)                 1
# 64    przynależne na ulicy (1 miejsce parkingowe)                 1
# 6856      brak przynależnego miejsca parkingowego                 1
# 4983                          w garażu podziemnym                 1
#
#       parking_own  parking_nan
# 5937            1            0
# 5238            0            0
# 6558            1            0
# 4287            1            1
# 4169            1            0
# 2696            1            0
# 3141            1            0
# 3170            1            1
# 6831            1            0
# 606             1            1
# 6575            0            0
# 1026            1            0
# 2708            1            1
# 1786            1            0
# 317             1            0
# 1599            1            0
# 6303            1            0
# 64              1            0
# 6856            0            0
# 4983            1            0

# %%
#corecting values in 'no_parking_space' by information from 'parking_own' in new col 'is_parking'
no_parking_df['is_parking'] = no_parking_df['no_parking_space'].apply(lambda x: 1 if x != 0 else 0)
no_parking_df.drop(columns=['no_parking_space'], inplace=True)
# Out:
# /var/folders/sh/pxc94xyx7jx4j8wws1vh_np80000gn/T/ipykernel_72353/1273714692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_parking_df['is_parking'] = no_parking_df['no_parking_space'].apply(lambda x: 1 if x != 0 else 0)
# /var/folders/sh/pxc94xyx7jx4j8wws1vh_np80000gn/T/ipykernel_72353/1273714692.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_parking_df.drop(columns=['no_parking_space'], inplace=True)

# %%
no.df['is_parking'] = no.df['no_parking_space'].apply(lambda x: 1 if x != 0 else 0)
no.df['parking_nan'] = no.df['parking_type'].apply(lambda x: 1 if x == 'none' else 0)
no.df.drop(columns=['no_parking_space', 'parking_type'], inplace=True)

# %%
created_parking_columns = ['is_parking', 'parking_nan']

no.unique_values(created_parking_columns)
# Out:
# UNIQUE VALUES FOR 'is_parking': 2
# Percentage of 'none' values for 'is_parking': 0.00%
# Unique values in 'is_parking': [1 0]
# UNIQUE VALUES FOR 'parking_nan': 2
# Percentage of 'none' values for 'parking_nan': 0.00%
# Unique values in 'parking_nan': [0 1]

# %% [markdown]
# ### Otodom

# %%
otodom.df.parking_type.unique()
# Out:
# array(['garage', 'none'], dtype=object)

# %%
otodom.unique_values(['parking_type'])
# Out:
# UNIQUE VALUES FOR 'parking_type': 2
# Percentage of 'none' values for 'parking_type': 38.72%
# Unique values in 'parking_type': ['garage' 'none']

# %%
otodom_parking_column = "parking_type"

otodom.df['is_parking'] = otodom.df[otodom_parking_column].apply(lambda x: 1 if x not in [None, 'NONE', 'none', 0, '0'] else 0
)
otodom.df['parking_nan'] = otodom.df[otodom_parking_column].apply(lambda x: 1 if x in [None, 'NONE', 'none'] else 0)
otodom.df.drop(columns=[otodom_parking_column], inplace=True)
print(otodom.df[['is_parking', 'parking_nan']].sample(10))
# Out:
#        is_parking  parking_nan
# 1908            0            1
# 4288            0            1
# 2727            0            1
# 8717            0            1
# 3768            1            0
# 2629            0            1
# 2597            0            1
# 10810           1            0
# 5421            1            0
# 11000           1            0

# %%
otodom.unique_values(created_parking_columns)
# Out:
# UNIQUE VALUES FOR 'is_parking': 2
# Percentage of 'none' values for 'is_parking': 0.00%
# Unique values in 'is_parking': [1 0]
# UNIQUE VALUES FOR 'parking_nan': 2
# Percentage of 'none' values for 'parking_nan': 0.00%
# Unique values in 'parking_nan': [0 1]

# %% [markdown]
# ### Morizon (same as Otodom)

# %%
morizon.df.columns
# Out:
# Index(['url', 'platform', 'transaction_type', 'property_type', 'city', 'id',
#        'total_area', 'district', 'prec_adress', 'row_price', 'row_price_m2',
#        'primery_market', 'property_level', 'total_property_level',
#        'description', 'market_type', 'building_type', 'no_rooms',
#        'kitchen_type', 'building_year', 'material', 'heating_type', 'water',
#        'elevator', 'gas', 'bath_with_wc', 'electricity', 'parking', 'basement',
#        'balcony'],
#       dtype='object')

# %%
morizon.df.parking.unique()
# Out:
# array([0.0, 1.0, 'none'], dtype=object)

# %%
morizon.unique_values(['parking'])
# Out:
# UNIQUE VALUES FOR 'parking': 3
# Percentage of 'none' values for 'parking': 0.64%
# Unique values in 'parking': [0.0 1.0 'none']

# %%
morizon_parking_column = "parking"

morizon.df['parking_nan'] = morizon.df[morizon_parking_column].apply(lambda x: 1 if x == 'none' else 0)
morizon.df['is_parking'] = morizon.df[morizon_parking_column].apply(lambda x: 1 if x not in [None, 'NONE', 'none'] else 0)

morizon.df.drop(columns=[morizon_parking_column], inplace=True)
morizon.df[['is_parking', 'parking_nan']].sample(10)
# Out:
#       is_parking  parking_nan
# 4494           1            0
# 1517           1            0
# 6299           1            0
# 6793           1            0
# 4733           1            0
# 2531           1            0
# 4270           1            0
# 3426           1            0
# 860            1            0
# 5010           0            1

# %%
morizon.unique_values(['is_parking', 'parking_nan'])
# Out:
# UNIQUE VALUES FOR 'is_parking': 2
# Percentage of 'none' values for 'is_parking': 0.00%
# Unique values in 'is_parking': [1 0]
# UNIQUE VALUES FOR 'parking_nan': 2
# Percentage of 'none' values for 'parking_nan': 0.00%
# Unique values in 'parking_nan': [0 1]

# %% [markdown]
# ## Match similar column and reneme part of them

# %% [markdown]
# ### Find same column names and check data

# %%
def find_common_columns(*dataframes):
    common_columns = set(dataframes[0].columns)
    for df in dataframes[1:]:
        common_columns.intersection_update(df.columns)
    return list(common_columns)

similar_column_names = find_common_columns(morizon.df, otodom.df, no.df)
similar_column_names
# Out:
# ['total_property_level',
#  'property_type',
#  'material',
#  'basement',
#  'heating_type',
#  'elevator',
#  'total_area',
#  'parking_nan',
#  'property_level',
#  'kitchen_type',
#  'url',
#  'is_parking',
#  'row_price_m2',
#  'no_rooms',
#  'district']

# %%
def convert_column_types(df, column_names, new_type):
    for column_name in column_names:
        try:
            if df[column_name].dtype == 'object':
                df[column_name] = df[column_name].str.strip().replace(' ', '')
            df[column_name] = df[column_name].astype(new_type)
        except Exception as e:
            print(f"@ {column_name}': {e}")
    return df

# %%
morizon.df[similar_column_names]
# Out:
#      total_property_level property_type material basement heating_type  \
# 0                     5.0    mieszkanie     none      1.0  CO miejskie
# 1                     5.0    mieszkanie     none      0.0         none
# 2                     5.0    mieszkanie     none      0.0         none
# 3                     7.0    mieszkanie     none      0.0    Centralne
# 4                     5.0    mieszkanie    Cegła      1.0    Centralne
# ...                   ...           ...      ...      ...          ...
# 7303                  1.0    mieszkanie    Cegła      1.0       Gazowe
# 7304                  4.0    mieszkanie     none      0.0  Co Miejskie
# 7305                  4.0    mieszkanie     none      0.0  Co Miejskie
# 7306                 none    mieszkanie     none      0.0         none
# 7307                 none    mieszkanie     none      0.0         none
#
#      elevator  total_area  parking_nan property_level kitchen_type  \
# 0         1.0          91            0            4.0    Oddzielna
# 1         1.0          70            0            3.0         none
# 2         1.0         110            0            3.0         none
# 3         1.0          76            0            5.0         none
# 4         1.0          86            0            1.0         none
# ...       ...         ...          ...            ...          ...
# 7303      0.0          83            0            1.0         none
# 7304      0.0          81            0            1.0         none
# 7305      0.0         100            0            1.0         none
# 7306      0.0          72            0           none         none
# 7307      0.0          79            0           none         none
#
#                                                     url  is_parking  \
# 0     https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 1     https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 2     https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 3     https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 4     https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# ...                                                 ...         ...
# 7303  https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 7304  https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 7305  https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 7306  https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
# 7307  https://www.morizon.pl/oferta/sprzedaz-mieszka...           1
#
#      row_price_m2 no_rooms        district
# 0          16 862      4.0         mokotow
# 1          22 125      3.0         bielany
# 2          22 125      3.0         ursynow
# 3          21 484      4.0         mokotow
# 4          19 302      4.0         ursynow
# ...           ...      ...             ...
# 7303       16 695      4.0          ochota
# 7304       17 113      4.0  praga poludnie
# 7305       17 113      4.0          wlochy
# 7306         none      3.0        zoliborz
# 7307         none      3.0          ochota
#
# [7308 rows x 15 columns]

# %%
otodom.df[similar_column_names]
# Out:
#       total_property_level property_type             material  basement  \
# 0                      7.0    mieszkanie                brick      none
# 1                     11.0    mieszkanie                brick      none
# 2                      5.0    mieszkanie                brick      none
# 3                      3.0    mieszkanie                brick      none
# 4                      4.0    mieszkanie                brick      none
# ...                    ...           ...                  ...       ...
# 11337                  4.0    mieszkanie  reinforced_concrete  basement
# 11338                  5.0    mieszkanie                brick  basement
# 11339                  1.0    mieszkanie                brick  basement
# 11340                  6.0    mieszkanie                brick      none
# 11341                  4.0    mieszkanie       concrete_plate  basement
#
#       heating_type elevator  total_area  parking_nan property_level  \
# 0            urban     none       79.19            0    ['floor_1']
# 1            urban      1.0       68.14            0    ['floor_4']
# 2       electrical      1.0       82.82            1    ['floor_4']
# 3            urban      1.0       73.50            0    ['floor_2']
# 4            urban     none       70.75            1    ['floor_3']
# ...            ...      ...         ...          ...            ...
# 11337        urban      1.0       67.81            0    ['floor_3']
# 11338        urban      1.0       89.00            0    ['floor_3']
# 11339        urban      1.0       30.00            0   ['floor_10']
# 11340        urban      1.0       46.00            0    ['floor_4']
# 11341        urban     none       55.50            0    ['floor_4']
#
#            kitchen_type                                                url  \
# 0      separate kitchen                mieszkanie-79-19-m-warszawa-ID4pzV9
# 1      separate kitchen  3-pokoje-moderna-osiedle-gotowe-do-wprowadzeni...
# 2                  none   trzypokojowe-mieszkanie-na-pradze-polnoc-ID4pAwp
# 3                  none              apartament-w-marinie-3-pokoje-ID4pCuq
# 4                  none        mieszkanie-w-sercu-starego-mokotowa-ID4pCJK
# ...                 ...                                                ...
# 11337              none  3-pok-klobucka-6a-komorka-obok-mieszkania-2gar...
# 11338              none            apartament-mokotow-chodkiewicza-ID4peUU
# 11339  separate kitchen                                          x-ID4p9qQ
# 11340  separate kitchen  warszawa-tarchomin-2-pokoje-46m2-po-remoncie-I...
# 11341              none                                   sprzedam-ID4p6Gg
#
#        is_parking row_price_m2 no_rooms       district
# 0               1      16290.0    ['3']         Bemowo
# 1               1      18491.0    ['3']         Bródno
# 2               0      15500.0    ['3']       Targówek
# 3               1      18367.0    ['3']          Żerań
# 4               0      22332.0    ['2']        Mokotów
# ...           ...          ...      ...            ...
# 11337           1      16222.0    ['2']        Ursynów
# 11338           1      33767.0    ['3']  Górny Mokotów
# 11339           1      33333.0    ['1']           none
# 11340           1      15196.0    ['2']      Tarchomin
# 11341           1      14414.0    ['4']         Bródno
#
# [11342 rows x 15 columns]

# %%
no.df[similar_column_names]
# Out:
#      total_property_level property_type          material basement  \
# 0                     4.0    Mieszkanie             False     True
# 1                     7.0    Mieszkanie  tradycyjna/cegła    False
# 2                     4.0    Mieszkanie  tradycyjna/cegła     True
# 3                     8.0    Mieszkanie             False    False
# 4                     4.0    Mieszkanie             False    False
# ...                   ...           ...               ...      ...
# 7037                  3.0    Mieszkanie             False    False
# 7038                  2.0    Mieszkanie             False     True
# 7039                  3.0    Mieszkanie             False    False
# 7040                  5.0    Mieszkanie             False    False
# 7041                 none    Mieszkanie             False     none
#
#      heating_type  elevator  total_area  parking_nan property_level  \
# 0        miejskie     False       85.00            0            1.0
# 1            none      True      106.00            0            2.0
# 2        miejskie     False       55.00            1            0.0
# 3        miejskie      True       65.52            1            4.0
# 4            none      True       69.76            0            2.0
# ...           ...       ...         ...          ...            ...
# 7037         none      True       46.93            0            0.0
# 7038     miejskie     False       51.95            0            1.0
# 7039         none      True       73.10            1            0.0
# 7040     miejskie      True       58.90            0            3.0
# 7041         none     False       69.00            1            8.0
#
#                      kitchen_type  \
# 0                         z oknem
# 1                  aneks kuchenny
# 2                       oddzielna
# 3                  aneks kuchenny
# 4                         z oknem
# ...                           ...
# 7037  aneks kuchenny, w zabudowie
# 7038               aneks kuchenny
# 7039               aneks kuchenny
# 7040               aneks kuchenny
# 7041                         none
#
#                                                     url  is_parking  \
# 0     https://warszawa.nieruchomosci-online.pl/miesz...           1
# 1     https://warszawa.nieruchomosci-online.pl/miesz...           1
# 2     https://warszawa.nieruchomosci-online.pl/miesz...           0
# 3     https://warszawa.nieruchomosci-online.pl/miesz...           0
# 4     https://warszawa.nieruchomosci-online.pl/miesz...           1
# ...                                                 ...         ...
# 7037  https://warszawa.nieruchomosci-online.pl/miesz...           1
# 7038  https://warszawa.nieruchomosci-online.pl/miesz...           1
# 7039  https://zamienie.nieruchomosci-online.pl/nowe-...           0
# 7040  https://warszawa.nieruchomosci-online.pl/miesz...           1
# 7041  https://warszawa.nieruchomosci-online.pl/miesz...           0
#
#       row_price_m2 no_rooms                district
# 0     12647.058824      4.0                 Ursynów
# 1     19905.660377      4.0                 Mokotów
# 2     34363.636364      2.0             Śródmieście
# 3     24267.399267      3.0                 Mokotów
# 4      21932.33945      3.0                 Wilanów
# ...            ...      ...                     ...
# 7037  23226.081398      2.0                 Ursynów
# 7038  15380.173244      2.0          Praga-Południe
# 7039          none      4.0  Thomasa Alva Edisona 1
# 7040  13921.901528      3.0               Białołęka
# 7041  25652.173913      3.0                 Mokotów
#
# [7042 rows x 15 columns]

# %%
similar_columns_to_celean_text = [
 'material',
 'no_rooms',
 'elevator',
 'district',
 'property_type',
 'row_price_m2',
 'total_area',
 'kitchen_type',
 'basement',
 'total_property_level',
 'heating_type', 
 'property_level']

for data_frame in portal_data_objects:
    data_frame.clean_text_data(similar_columns_to_celean_text)
    if data_frame.df[similar_columns_to_celean_text].isnull().any().any():
        print("Istnieją wartości NaN w danych - zostały zastąpione na 'NONE")
        data_frame.complete_none()

# %%
def create_similar_dataframe(column_names_list, **dataframes):
    sorted_columns = sorted(column_names_list)
    
    prefixed_dataframe = pd.DataFrame()

    for col in sorted_columns:
        for platform, df in dataframes.items():
            prefixed_column = f"{platform}_{col}"
            if col in df.columns:
                prefixed_dataframe[prefixed_column] = df[col]
            
    return prefixed_dataframe

sorted_df_with_prefix = create_similar_dataframe(similar_column_names, morizon=morizon.df, otodom=otodom.df, no=no.df)
sorted_df_with_prefix.columns
# Out:
# Index(['morizon_basement', 'otodom_basement', 'no_basement',
#        'morizon_district', 'otodom_district', 'no_district',
#        'morizon_elevator', 'otodom_elevator', 'no_elevator',
#        'morizon_heating_type', 'otodom_heating_type', 'no_heating_type',
#        'morizon_is_parking', 'otodom_is_parking', 'no_is_parking',
#        'morizon_kitchen_type', 'otodom_kitchen_type', 'no_kitchen_type',
#        'morizon_material', 'otodom_material', 'no_material',
#        'morizon_no_rooms', 'otodom_no_rooms', 'no_no_rooms',
#        'morizon_parking_nan', 'otodom_parking_nan', 'no_parking_nan',
#        'morizon_property_level', 'otodom_property_level', 'no_property_level',
#        'morizon_property_type', 'otodom_property_type', 'no_property_type',
#        'morizon_row_price_m2', 'otodom_row_price_m2', 'no_row_price_m2',
#        'morizon_total_area', 'otodom_total_area', 'no_total_area',
#        'morizon_total_property_level', 'otodom_total_property_level',
#        'no_total_property_level', 'morizon_url', 'otodom_url', 'no_url'],
#       dtype='object')

# %%
similar_columns = {
#numerical
'row_price_m2', #predicted value / decision atribute is price
'no_rooms',
'property_level',
'total_area',
'total_property_level',

#True / False
'basement',
'elevator',

#Categorical
'heating_type',
'kitchen_type',
'material',
'property_type',
'district',

#Not checking
'parking_nan',
'is_parking',
'url'}

# %%
def display_sample_with_columns_list(dataframe, columns):
    filtered_columns = [col for col in dataframe.columns if any(substring in col for substring in columns)]
    filtered_df = dataframe[filtered_columns]
    if not filtered_df.empty:
        for col in filtered_df.columns:
            unique_values = len(filtered_df[col].unique())
            none_percentage = (filtered_df[col] == 'none').mean() * 100
            print(f"UNIQUE VALUES FOR '{col}': {unique_values}")
            print(f"Percentage of 'none' values for '{col}': {none_percentage:.2f}%")
            if unique_values < 6:
                print(f"Unique values in '{col}': {filtered_df[col].unique()}")
        return filtered_df.sample(6)
    else:
        return pd.DataFrame(columns=filtered_columns).sample(6)

# %%
def generate_column_value_dataframe(portal_data_objects, column_name, value_type=None):
    # Creating new dataframe with given column

    column_dfs = [obj.df[[column_name]] for obj in portal_data_objects if column_name in obj.df.columns]
    
    # Combining all dataframes into one
    combined_df = pd.concat(column_dfs, ignore_index=True)
    
    # Calculating the percentage of unique values
    value_counts = combined_df[column_name].value_counts(normalize=True) * 100
    
    # Rounding to 1 decimal place and adding %
    value_counts = value_counts.round(1).astype(str) + '%'
    
    # Displaying results
    if value_type:
        value_counts = value_counts[value_counts.index.map(lambda x: isinstance(x, value_type))]
    
    print(value_counts)

# %% [markdown]
# ##### row_price_m2
# - morizon: NONE > 33%
#
# This is a decision-related argument, hence its analysis will take place at the very beginning, due to the potential removal of some rows. In the next section, a more extensive analysis of the PRICE / ROW_PRICE column will take place after renaming the arguments

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['row_price_m2'])
# Out:
# UNIQUE VALUES FOR 'morizon_row_price_m2': 2698
# Percentage of 'none' values for 'morizon_row_price_m2': 33.68%
# UNIQUE VALUES FOR 'otodom_row_price_m2': 4155
# Percentage of 'none' values for 'otodom_row_price_m2': 6.44%
# UNIQUE VALUES FOR 'no_row_price_m2': 4734
# Percentage of 'none' values for 'no_row_price_m2': 1.01%
#      morizon_row_price_m2 otodom_row_price_m2 no_row_price_m2
# 6083                 none             16001.0      16350.7109
# 3575               26 875             23200.0    17995.689655
# 2902                 none             31364.0    19459.459459
# 2369               14 180             23226.0         15000.0
# 2668                 none                none    23513.234789
# 2623               19 213             19459.0    28814.814815

# %% [markdown]
# ##### Morizon

# %%
morizon.df[morizon.df['row_price_m2'] == 'none'][['row_price_m2', 'row_price', 'total_area', 'market_type', 'primery_market']]
# Out:
#      row_price_m2 row_price  total_area market_type primery_market
# 5            none      none         117   pierwotny           none
# 6            none      none          75   pierwotny           none
# 7            none      none         119   pierwotny           none
# 8            none      none          89   pierwotny           none
# 13           none      none          66   pierwotny           none
# ...           ...       ...         ...         ...            ...
# 7236         none      none          66   pierwotny           none
# 7264         none      none          74   pierwotny           none
# 7296         none      none         100        none           none
# 7306         none      none          72   pierwotny           none
# 7307         none      none          79   pierwotny           none
#
# [2461 rows x 5 columns]

# %%
morizon.df[morizon.df['row_price'] != morizon.df['primery_market']]
# Out:
# Empty DataFrame
# Columns: [url, platform, transaction_type, property_type, city, id, total_area, district, prec_adress, row_price, row_price_m2, primery_market, property_level, total_property_level, description, market_type, building_type, no_rooms, kitchen_type, building_year, material, heating_type, water, elevator, gas, bath_with_wc, electricity, basement, balcony, parking_nan, is_parking]
# Index: []
#
# [0 rows x 31 columns]

# %%
morizon.df[(morizon.df['row_price_m2'] == 'none') & (morizon.df['market_type'] != 'pierwotny')][['row_price_m2', 'row_price', 'total_area', 'market_type', 'primery_market']]
# Out:
#      row_price_m2 row_price  total_area market_type primery_market
# 1130         none      none          61        none           none
# 1131         none      none          61        none           none
# 1138         none      none          51        none           none
# 1139         none      none          51        none           none
# 1143         none      none          50        none           none
# 1144         none      none          50        none           none
# 1385         none      none          60        none           none
# 1386         none      none          60        none           none
# 1392         none      none          57        none           none
# 1393         none      none          57        none           none
# 1655         none      none          68        none           none
# 1907         none      none          61        none           none
# 1911         none      none          61        none           none
# 2279         none      none          42        none           none
# 2393         none      none          55        none           none
# 2399         none      none          54        none           none
# 2736         none      none          39        none           none
# 2798         none      none          61        none           none
# 2876         none      none          32        none           none
# 2877         none      none          32        none           none
# 3477         none      none          52        none           none
# 3478         none      none          55        none           none
# 5010         none      none          64        none           none
# 5011         none      none          64        none           none
# 5269         none      none          94        none           none
# 5270         none      none          94        none           none
# 5271         none      none          94        none           none
# 5272         none      none          94        none           none
# 5273         none      none          94        none           none
# 5325         none      none         367        none           none
# 5488         none      none          28        none           none
# 5489         none      none          28        none           none
# 5500         none      none         113        none           none
# 5501         none      none         113        none           none
# 5988         none      none          35        none           none
# 5989         none      none          50        none           none
# 6048         none      none          54        none           none
# 7076         none      none         140        none           none
# 7097         none      none          37        none           none
# 7120         none      none          44        none           none
# 7121         none      none          64        none           none
# 7122         none      none          44        none           none
# 7151         none      none          54        none           none
# 7152         none      none          48        none           none
# 7176         none      none          60        none           none
# 7177         none      none          58        none           none
# 7296         none      none         100        none           none

# %% [markdown]
# For morizon, if row_price_m2 == 'NONE':
#
# - in about 50 cases the price and market type is NONE
# - for about 2400 cases is unknown
#
# For real estate price prediction row_price_2 or row_price will be key, hence rows are unnecessary -> 33% of dataframe morizon

# %%
otodom.df[(otodom.df['row_price_m2'] == 'none')][['row_price_m2', 'price', 'total_area', 'market_type']]
# Out:
#       row_price_m2 price  total_area market_type
# 20            none  none       31.33     PRIMARY
# 22            none  none       42.67     PRIMARY
# 86            none  none       69.63     PRIMARY
# 88            none  none       38.69     PRIMARY
# 92            none  none       73.62     PRIMARY
# ...            ...   ...         ...         ...
# 11269         none  none       46.81     PRIMARY
# 11275         none  none       53.64     PRIMARY
# 11276         none  none       47.18     PRIMARY
# 11287         none  none       53.02     PRIMARY
# 11291         none  none       79.25     PRIMARY
#
# [965 rows x 4 columns]

# %%
otodom.df[(otodom.df['row_price_m2'] == 'none') & (otodom.df['market_type'] != 'PRIMARY')][['row_price_m2', 'price', 'total_area', 'market_type']]
# Out:
# Empty DataFrame
# Columns: [row_price_m2, price, total_area, market_type]
# Index: []

# %%
no.df[(no.df['row_price_m2'] == 'none')][['row_price_m2', 'price', 'total_area', 'makret_type']]
# Out:
#      row_price_m2 price  total_area makret_type
# 1544         none  none       26.00        none
# 6647         none  none       75.00   pierwotny
# 6648         none  none       75.00   pierwotny
# 6653         none  none       66.08   pierwotny
# 6656         none  none       54.12   pierwotny
# ...           ...   ...         ...         ...
# 7032         none  none       64.00   pierwotny
# 7033         none  none       62.51   pierwotny
# 7034         none  none       72.15   pierwotny
# 7035         none  none       75.05   pierwotny
# 7039         none  none       73.10   pierwotny
#
# [74 rows x 4 columns]

# %%
no.df[(no.df['row_price_m2'] == 'none') & (no.df['makret_type'] != 'pierwotny')][['row_price_m2', 'price', 'total_area', 'makret_type']]
# Out:
#      row_price_m2 price  total_area makret_type
# 1544         none  none        26.0        none

# %%
for data_frame in portal_data_objects:
    data_frame.df.drop(data_frame.df[data_frame.df['row_price_m2'] == 'none'].index, inplace=True)
    # Removing all spaces from strings
    data_frame.df['row_price_m2'] = data_frame.df['row_price_m2'].astype(str).str.replace(' ', '').astype(float).astype(int)
    data_frame.convert_column_types(['row_price_m2'], int)
    data_frame.unique_values(['row_price_m2'])
# Out:
# UNIQUE VALUES FOR 'row_price_m2': 2697
# Percentage of 'none' values for 'row_price_m2': 0.00%
# UNIQUE VALUES FOR 'row_price_m2': 5602
# Percentage of 'none' values for 'row_price_m2': 0.00%
# UNIQUE VALUES FOR 'row_price_m2': 4123
# Percentage of 'none' values for 'row_price_m2': 0.00%

# %% [markdown]
# ##### no_rooms
# - Otodom, change ['3'], ['5'] format for 3, 5
# - Otodom, change ['more', 'NONE', {>8 values} for 100]
#
# All -> change for int not float

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['no_rooms'])
# Out:
# UNIQUE VALUES FOR 'morizon_no_rooms': 11
# Percentage of 'none' values for 'morizon_no_rooms': 0.67%
# UNIQUE VALUES FOR 'otodom_no_rooms': 10
# Percentage of 'none' values for 'otodom_no_rooms': 0.00%
# UNIQUE VALUES FOR 'no_no_rooms': 16
# Percentage of 'none' values for 'no_no_rooms': 0.34%
#      morizon_no_rooms otodom_no_rooms no_no_rooms
# 5919              2.0               2         5.0
# 7221              4.0               2         NaN
# 5697              4.0               4         2.0
# 1497              2.0               2         3.0
# 2817              4.0               5         3.0
# 1721              1.0               2         3.0

# %%
otodom.df['no_rooms'].unique()
# Out:
# array(['3', '2', '4', '1', '5', '8', '6', '7', 'more', '9', '10'],
#       dtype=object)

# %%
generate_column_value_dataframe(portal_data_objects, 'no_rooms', str)
# Out:
# no_rooms
# 3       17.0%
# 2       16.8%
# 4        6.3%
# 1        4.4%
# 5        1.8%
# 6        0.3%
# none     0.1%
# 7        0.1%
# more     0.1%
# 8        0.0%
# 10       0.0%
# 9        0.0%
# Name: proportion, dtype: object

# %%
max_number_of_rooms = 9

for data_frame in portal_data_objects:
    data_frame.df = data_frame.df.astype(str)
    data_frame.df['no_rooms'] = data_frame.df['no_rooms'].replace('none', '100')
    data_frame.df['no_rooms'] = data_frame.df['no_rooms'].replace('more', '100')  # Replace 'none' with 100
    # Conversion of the number of rooms to int type, with special cases
    data_frame.df['no_rooms'] = data_frame.df['no_rooms'].apply(lambda x: int(x))
    data_frame.df['no_rooms'] = data_frame.df['no_rooms'].apply(lambda x: 100 if x > max_number_of_rooms else x)

generate_column_value_dataframe(portal_data_objects, 'no_rooms')
# Out:
# no_rooms
# 3      36.3%
# 2      36.2%
# 4      13.1%
# 1       9.8%
# 5       3.4%
# 6       0.6%
# 100     0.2%
# 7       0.2%
# 8       0.1%
# 9       0.0%
# Name: proportion, dtype: object

# %% [markdown]
# ##### property level AND total_property_level
# - otodom: ['floor_3']	== 3, ['ground_floor']	== 0
# - morizon: NONE for property_level == total_property_level, primery_market? NOT ALWAYS
# - all platfroms -> int()

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['property_level'])
# Out:
# UNIQUE VALUES FOR 'morizon_property_level': 23
# Percentage of 'none' values for 'morizon_property_level': 23.75%
# UNIQUE VALUES FOR 'otodom_property_level': 15
# Percentage of 'none' values for 'otodom_property_level': 2.26%
# UNIQUE VALUES FOR 'no_property_level': 32
# Percentage of 'none' values for 'no_property_level': 0.66%
# UNIQUE VALUES FOR 'morizon_total_property_level': 30
# Percentage of 'none' values for 'morizon_total_property_level': 23.75%
# UNIQUE VALUES FOR 'otodom_total_property_level': 32
# Percentage of 'none' values for 'otodom_total_property_level': 3.05%
# UNIQUE VALUES FOR 'no_total_property_level': 35
# Percentage of 'none' values for 'no_total_property_level': 3.00%
#      morizon_property_level otodom_property_level no_property_level  \
# 2207                   none               floor 1               2.0
# 3097                   none          ground floor               1.0
# 5891                   none               floor 1               3.0
# 739                     1.0               floor 2               2.0
# 6517                    2.0               floor 1               7.0
# 3374                   none                  none              12.0
#
#      morizon_total_property_level otodom_total_property_level  \
# 2207                         none                         4.0
# 3097                         none                         2.0
# 5891                         none                         4.0
# 739                           4.0                         8.0
# 6517                          2.0                         3.0
# 3374                         none                        10.0
#
#      no_total_property_level
# 2207                     4.0
# 3097                     4.0
# 5891                     4.0
# 739                      3.0
# 6517                     7.0
# 3374                    12.0

# %% [markdown]
# ###### otodom specyfic

# %%
otodom.df['property_level'].unique()
# Out:
# array(['floor 1', 'floor 4', 'floor 2', 'floor 3', 'ground floor', 'none',
#        'floor 5', 'floor 7', 'floor 10', 'floor 6', 'floor 9',
#        'floor higher 10', 'floor 8', 'cellar', 'garret'], dtype=object)

# %%
otodom.df['property_level'] = otodom.df['property_level'].replace("ground floor", 0)
otodom.df['property_level'] = otodom.df['property_level'].replace("cellar", 111) #for string transformation
otodom.df['property_level'] = otodom.df['property_level'].replace("floor higher 10", 100)

otodom.df['property_level'] = otodom.df.apply(lambda row: row['total_property_level'] if row['property_level'] == "garret" else row['property_level'], axis=1)

otodom.df['property_level'].unique()
# Out:
# array(['floor 1', 'floor 4', 'floor 2', 'floor 3', 0, 'none', 'floor 5',
#        'floor 7', 'floor 10', 'floor 6', 'floor 9', 100, 'floor 8', 111,
#        11.0, 52.0, 2.0, 10.0], dtype=object)

# %%
otodom.df['property_level'] = otodom.df['property_level'].astype(str).str.extract('(\d+)')
otodom.df['property_level'] = otodom.df['property_level'].astype(float)
otodom.df['property_level'] = otodom.df['property_level'].replace(111, -1) #after string transformation
otodom.df['property_level'] = otodom.df['property_level'].replace({np.nan: 'none'}) #same as in other columns

otodom.df['property_level'].unique() #ground floor, cellar, garret, floor higher 10
# Out:
# array([1.0, 4.0, 2.0, 3.0, 0.0, 'none', 5.0, 7.0, 10.0, 6.0, 9.0, 100.0,
#        8.0, -1.0, 11.0, 52.0], dtype=object)

# %%
generate_column_value_dataframe(portal_data_objects, 'property_level', value_type=str)
# Out:
# property_level
# none    4.9%
# Name: proportion, dtype: object

# %%
otodom.df[otodom.df['property_level'] == 'none'][['property_level', 'total_property_level']]
# Out:
#       property_level total_property_level
# 8               none                  3.0
# 29              none                 none
# 32              none                  4.0
# 368             none                  6.0
# 414             none                  6.0
# ...              ...                  ...
# 10897           none                 none
# 10910           none                  1.0
# 11232           none                  1.0
# 11233           none                  1.0
# 11260           none                 none
#
# [248 rows x 2 columns]

# %% [markdown]
# ###### morizon specyfic

# %%
morizon.df[morizon.df['property_level'] == 'none'][['property_level', 'total_property_level', 'market_type']]
# Out:
#      property_level total_property_level market_type
# 22             none                 none      wtorny
# 23             none                 none      wtorny
# 25             none                 none      wtorny
# 50             none                 none      wtorny
# 51             none                 none      wtorny
# ...             ...                  ...         ...
# 7283           none                 none   pierwotny
# 7289           none                 none   pierwotny
# 7290           none                 none   pierwotny
# 7295           none                 none   pierwotny
# 7297           none                 none   pierwotny
#
# [788 rows x 3 columns]

# %%
print(morizon.df[(morizon.df['property_level'] == 'none') & (morizon.df['total_property_level'] != 'none')][['property_level', 'total_property_level', 'market_type']])
# Out:
# Empty DataFrame
# Columns: [property_level, total_property_level, market_type]
# Index: []

# %%
unique_market_type_percentage = morizon.df[morizon.df['property_level'] == 'none']['market_type'].value_counts(normalize=True) * 100
display(unique_market_type_percentage)
# Out:
# market_type
# wtorny       75.126904
# pierwotny    24.873096
# Name: proportion, dtype: float64

# %% [markdown]
# For Morizon:
# - if property_level == 'NONE', total_property_level == 'NONE'
# - market_type has no relation to the above condition

# %%
for data_frame in portal_data_objects:
    data_frame.create_nan_column(['property_level', 'total_property_level'])
    
    data_frame.df['property_level'] = data_frame.df['property_level'].apply(lambda x: 100 if x == 'none' else x).astype(int)
    data_frame.df['total_property_level'] = data_frame.df['total_property_level'].apply(lambda x: 100 if x == 'none' else x).astype(int)
    
    print(f"property_level: {data_frame.df['property_level'].unique()}")
    print(f"total_property_level: {data_frame.df['total_property_level'].unique()}")
# Out:
# property_level: [  4   3   5   1   2 100   6  10   9   7  14   8  12  17  11  15  22  13
#   20  16  23  18  24]
# total_property_level: [  5   7   1   3   4   2 100   9  10   6  12  14  15  11   8  13  17  19
#   26  16  22  18  24  44  25  23  30  20  21  28]
# property_level: [  1   4   2   3   0 100   5   7  10   6   9   8  -1  11  52]
# total_property_level: [   7   11    5    3    4    2    9   12    8   10  100   15    6    1
#    52   14   30   21   13   16   18   17   25   22   27   23   20   24
#    19   29   28   31   26   44 2019  106]
# property_level: [  1   2   0   4   5   3  10   6   7  11   8   9  18 100  19  17  15  20
#   12  14  16  24  28  13  31  52  23  51  22  29  30]
# total_property_level: [  4   7   8   2   6   5   1  10   3 100  14  15  11  13  12  18  17   9
#   16  30  23  20  25  24  22  19  26  44  29  28  52  27  21 106]

# %%
# Code for fixing errors - at the visualization stage before the model, not cleaning data - for identification of dependencies in the entire set
# Changing values greater than 46 to 100 in specific columns for all DataFrame objects in portal_data_objects
highest_level_cut = 21
property_level_columns = ['property_level', 'total_property_level']

for data_frame in portal_data_objects:
    for column in property_level_columns:
        data_frame.df[column] = data_frame.df[column].astype(int)
        #change outliers to 100 (uknnown)
        data_frame.df[column] = data_frame.df[column].apply(lambda x: 100 if x > highest_level_cut else x)
        data_frame.convert_column_types(property_level_columns, float)

# %%
generate_column_value_dataframe(portal_data_objects, 'property_level')
# Out:
# property_level
#  1.0      19.6%
#  2.0      17.7%
#  3.0      14.8%
#  4.0      11.1%
#  0.0      10.6%
#  5.0       6.0%
#  100.0     5.9%
#  6.0       4.6%
#  7.0       3.3%
#  8.0       2.3%
#  9.0       1.6%
#  10.0      1.4%
#  11.0      0.3%
#  12.0      0.2%
#  14.0      0.1%
#  17.0      0.1%
#  13.0      0.1%
#  15.0      0.1%
#  16.0      0.1%
#  20.0      0.0%
#  18.0      0.0%
# -1.0       0.0%
#  19.0      0.0%
# Name: proportion, dtype: object

# %%
generate_column_value_dataframe(portal_data_objects, 'total_property_level')
# Out:
# total_property_level
# 4.0      18.9%
# 3.0      15.0%
# 5.0      11.0%
# 10.0      8.3%
# 7.0       8.0%
# 6.0       7.5%
# 100.0     6.8%
# 2.0       6.7%
# 8.0       6.2%
# 11.0      2.6%
# 9.0       2.3%
# 12.0      1.7%
# 15.0      1.6%
# 1.0       1.1%
# 13.0      0.6%
# 16.0      0.5%
# 17.0      0.5%
# 14.0      0.4%
# 18.0      0.1%
# 19.0      0.1%
# 20.0      0.1%
# 21.0      0.0%
# Name: proportion, dtype: object

# %% [markdown]
# ##### total_area
# - all platforms -> float()

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['total_area'])
# Out:
# UNIQUE VALUES FOR 'morizon_total_area': 197
# Percentage of 'none' values for 'morizon_total_area': 0.00%
# UNIQUE VALUES FOR 'otodom_total_area': 2572
# Percentage of 'none' values for 'otodom_total_area': 0.00%
# UNIQUE VALUES FOR 'no_total_area': 2137
# Percentage of 'none' values for 'no_total_area': 0.00%
#       morizon_total_area  otodom_total_area  no_total_area
# 1075                  71              65.18          67.80
# 5500                 113              54.93         155.00
# 7139                  42              62.00            NaN
# 2492                  86              48.50          86.17
# 6606                 103              38.00          36.22
# 6546                  56              49.40          69.00

# %%
total_area_min_cut = 18
total_area_max_cut = 195

for data_frame in portal_data_objects:
    data_frame.convert_column_types(['total_area'], float)
    print(f"Number of rows: {len(data_frame.df['total_area'])}")
    print("Smallest values of total_area (from 15. index): ", sorted(data_frame.df['total_area'].unique())[15:25])
    print("Largest values of total_area (from 20. index): ", sorted(data_frame.df['total_area'].unique(), reverse=True)[20:30])
    print(f"Percentage of observations with 'total_area' < {total_area_min_cut}: {round((data_frame.df['total_area'] < total_area_min_cut).sum() / len(data_frame.df) * 100, 2)}%")
    print(f"Percentage of observations with 'total_area' > {total_area_max_cut}: {round((data_frame.df['total_area'] > total_area_max_cut).sum() / len(data_frame.df) * 100, 2)}%\n")
# Out:
# Number of rows: 4847
# Smallest values of total_area (from 15. index):  [29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0]
# Largest values of total_area (from 20. index):  [224.0, 222.0, 220.0, 213.0, 205.0, 203.0, 200.0, 197.0, 196.0, 195.0]
# Percentage of observations with 'total_area' < 18: 0.21%
# Percentage of observations with 'total_area' > 195: 0.7%
#
# Number of rows: 10377
# Smallest values of total_area (from 15. index):  [16.24, 16.25, 16.26, 17.0, 17.26, 17.29, 17.5, 17.57, 17.7, 18.0]
# Largest values of total_area (from 20. index):  [347.7, 336.0, 333.2, 333.19, 319.0, 317.0, 316.0, 303.0, 300.34, 300.3]
# Percentage of observations with 'total_area' < 18: 0.32%
# Percentage of observations with 'total_area' > 195: 1.37%
#
# Number of rows: 6968
# Smallest values of total_area (from 15. index):  [18.44, 18.62, 19.0, 20.0, 20.11, 20.13, 20.66, 20.82, 20.9, 21.0]
# Largest values of total_area (from 20. index):  [274.21, 274.03, 274.0, 271.0, 267.0, 262.0, 254.38, 254.0, 252.0, 250.0]
# Percentage of observations with 'total_area' < 18: 0.19%
# Percentage of observations with 'total_area' > 195: 1.13%

# %%
for data_frame in portal_data_objects:
    print(data_frame.df["total_area"].dtype)

    data_frame.df.drop(data_frame.df[data_frame.df['total_area'] <total_area_min_cut ].index, inplace=True)
    data_frame.df.drop(data_frame.df[data_frame.df['total_area'] > total_area_max_cut ].index, inplace=True)

    print(f"Number of rows: {len(data_frame.df['total_area'])}")
    print(f"Percentage of observations (after transformation) with 'total_area' < {total_area_min_cut}: {round((data_frame.df['total_area'] < total_area_min_cut).sum() / len(data_frame.df) * 100, 2)}%")
    print(f"Percentage of observations (after transformation) with 'total_area' > {total_area_max_cut}: {round((data_frame.df['total_area'] > total_area_max_cut).sum() / len(data_frame.df) * 100, 2)}%\n")
# Out:
# float64
# Number of rows: 4803
# Percentage of observations (after transformation) with 'total_area' < 18: 0.0%
# Percentage of observations (after transformation) with 'total_area' > 195: 0.0%
#
# float64
# Number of rows: 10202
# Percentage of observations (after transformation) with 'total_area' < 18: 0.0%
# Percentage of observations (after transformation) with 'total_area' > 195: 0.0%
#
# float64
# Number of rows: 6876
# Percentage of observations (after transformation) with 'total_area' < 18: 0.0%
# Percentage of observations (after transformation) with 'total_area' > 195: 0.0%

# %% [markdown]
# #####  basement:
# - OTODOM: change 'basement' in basement == 1, NONE == 0
# - NO: change True == 1, False == 0
#
# For all platrofms:
# if NONE in basement:
# - NONE = 0
# - basement_nan == 1 (else 0)
#
# !!! Together with elevator below

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['basement'])
# Out:
# UNIQUE VALUES FOR 'morizon_basement': 3
# Percentage of 'none' values for 'morizon_basement': 0.64%
# Unique values in 'morizon_basement': [1.0 0.0 'none']
# UNIQUE VALUES FOR 'otodom_basement': 2
# Percentage of 'none' values for 'otodom_basement': 68.25%
# Unique values in 'otodom_basement': ['none' 'basement']
# UNIQUE VALUES FOR 'no_basement': 4
# Percentage of 'none' values for 'no_basement': 23.13%
# Unique values in 'no_basement': [True False 'none' nan]
#      morizon_basement otodom_basement no_basement
# 723               0.0            none        True
# 1416              0.0            none        True
# 2565              1.0            none       False
# 6494              1.0            none       False
# 4976              0.0        basement        True
# 6981              0.0        basement        True

# %% [markdown]
# #####  elevator
# - Otodom: NONE == 0
# - NO: True == 1, False == 0,

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['elevator'])
# Out:
# UNIQUE VALUES FOR 'morizon_elevator': 3
# Percentage of 'none' values for 'morizon_elevator': 0.64%
# Unique values in 'morizon_elevator': [1.0 0.0 'none']
# UNIQUE VALUES FOR 'otodom_elevator': 2
# Percentage of 'none' values for 'otodom_elevator': 29.63%
# Unique values in 'otodom_elevator': ['none' 1.0]
# UNIQUE VALUES FOR 'no_elevator': 3
# Percentage of 'none' values for 'no_elevator': 0.00%
# Unique values in 'no_elevator': [False True nan]
#      morizon_elevator otodom_elevator no_elevator
# 955               0.0             1.0       False
# 238               0.0             1.0       False
# 302               0.0             1.0       False
# 2418              0.0             1.0       False
# 695               1.0             1.0       False
# 7000              1.0             1.0        True

# %%
binary_columns = ['elevator', 'basement']


for data_frame in portal_data_objects:
    data_frame.create_nan_column(binary_columns)
    if data_frame == no:
        data_frame.convert_bool_to_int(binary_columns)
    elif data_frame == otodom:
        otodom.df['basement'] = otodom.df['basement'].apply(lambda x: 1 if x == 'basement' else 0)
    data_frame.replace_none_with_binary(binary_columns)
    data_frame.convert_column_types(binary_columns, int)
    data_frame.unique_values(binary_columns)
# Out:
# UNIQUE VALUES FOR 'elevator': 2
# Percentage of 'none' values for 'elevator': 0.00%
# Unique values in 'elevator': [1 0]
# UNIQUE VALUES FOR 'basement': 2
# Percentage of 'none' values for 'basement': 0.00%
# Unique values in 'basement': [1 0]
# UNIQUE VALUES FOR 'elevator': 2
# Percentage of 'none' values for 'elevator': 0.00%
# Unique values in 'elevator': [0 1]
# UNIQUE VALUES FOR 'basement': 2
# Percentage of 'none' values for 'basement': 0.00%
# Unique values in 'basement': [0 1]
# UNIQUE VALUES FOR 'elevator': 2
# Percentage of 'none' values for 'elevator': 0.00%
# Unique values in 'elevator': [0 1]
# UNIQUE VALUES FOR 'basement': 2
# Percentage of 'none' values for 'basement': 0.00%
# Unique values in 'basement': [1 0]

# %%
otodom.df.basement.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ##### heating_type
# - Potentialy 33 cases (Morizon)
# - NONE values on very high level
# - other dictionaries.
#
# To analyse - if used, heating_nan needed for NO

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['heating_type'])
# Out:
# UNIQUE VALUES FOR 'morizon_heating_type': 34
# Percentage of 'none' values for 'morizon_heating_type': 56.87%
# UNIQUE VALUES FOR 'otodom_heating_type': 7
# Percentage of 'none' values for 'otodom_heating_type': 27.79%
# UNIQUE VALUES FOR 'no_heating_type': 14
# Percentage of 'none' values for 'no_heating_type': 49.49%
#        morizon_heating_type otodom_heating_type no_heating_type
# 2910                   none               urban            none
# 2516    ogrzewanie miejskie                 gas            none
# 144             co miejskie                none        miejskie
# 753   c o z sieci miejskiej                none            none
# 660   c o z sieci miejskiej                none            none
# 2372                   none               urban            none

# %%
morizon.create_nan_column(['heating_type'])
morizon.df['heating_type'] = morizon.df['heating_type'].str.lower().str.strip()
morizon.df['heating_type'].unique()
# Out:
# array(['co miejskie', 'none', 'centralne', 'gazowe', 'co własne',
#        'miejskie', 'c o z sieci miejskiej', 'ogrzewanie miejskie',
#        'c o miejskie', 'elektryczne', 'c o własne', 'c o gazowe',
#        'co z własnej kotłowni', 'pompa ciepła',
#        'ogrzewanie na gaz miejski', 'c o gazowe inne',
#        'c o gazowe c o własne', 'c o lokalne', 'ekologiczne', 'piec',
#        'piec pompa ciepła', 'inne', 'c o gazowe piec',
#        'ogrzewanie elektryczne', 'c o elektryczne', 'własne gazowe',
#        'z własnej kotłowni', 'eta owe', 'c o elektryczne c o gazowe',
#        'zroznicowane', 'własne dla budynku', 'własne gazowe junkers',
#        'gazowe budynkowe'], dtype=object)

# %%
otodom.create_nan_column(['heating_type'])
otodom.df['heating_type'] = otodom.df['heating_type'].str.lower().str.strip()
otodom.df['heating_type'].unique()
# Out:
# array(['urban', 'electrical', 'none', 'other', 'gas', 'boiler room',
#        'tiled stove'], dtype=object)

# %%
no.create_nan_column(['heating_type'])
no.df['heating_type'] = no.df['heating_type'].str.lower().str.strip()
no.df['heating_type'].unique()
# Out:
# array(['miejskie', 'none', 'gazowe', 'centralne ogrzewanie', 'własne',
#        'inne', 'elektryczne', 'pompa ciepła', 'piec', 'olej opałowy',
#        'co z własnej kotłowni', 'kominek', 'podłogowe'], dtype=object)

# %%
generate_column_value_dataframe(portal_data_objects, 'heating_type', str)
# Out:
# heating_type
# none                          36.4%
# urban                         29.7%
# miejskie                      16.0%
# co miejskie                    5.3%
# c o z sieci miejskiej          4.2%
# gas                            1.9%
# other                          1.8%
# gazowe                         1.3%
# c o miejskie                   0.5%
# boiler room                    0.4%
# własne                         0.3%
# ogrzewanie miejskie            0.3%
# centralne                      0.3%
# c o gazowe                     0.3%
# centralne ogrzewanie           0.3%
# electrical                     0.2%
# co własne                      0.1%
# c o własne                     0.1%
# pompa ciepła                   0.1%
# elektryczne                    0.1%
# inne                           0.1%
# ogrzewanie na gaz miejski      0.1%
# co z własnej kotłowni          0.0%
# c o gazowe c o własne          0.0%
# piec                           0.0%
# własne gazowe                  0.0%
# tiled stove                    0.0%
# c o elektryczne                0.0%
# c o lokalne                    0.0%
# z własnej kotłowni             0.0%
# własne dla budynku             0.0%
# gazowe budynkowe               0.0%
# c o gazowe piec                0.0%
# własne gazowe junkers          0.0%
# zroznicowane                   0.0%
# c o elektryczne c o gazowe     0.0%
# eta owe                        0.0%
# ogrzewanie elektryczne         0.0%
# piec pompa ciepła              0.0%
# ekologiczne                    0.0%
# c o gazowe inne                0.0%
# olej opałowy                   0.0%
# kominek                        0.0%
# podłogowe                      0.0%
# Name: proportion, dtype: object

# %%
heating_types_dict = {
    "urban": [
        'miejskie', 'c o miejskie', 'c o z sieci miejskiej', 'ogrzewanie miejskie', 'co miejskie'
    ],
    "central": [
        'centralne', 'centralne ogrzewanie', 'c o', 'c o elektryczne c o z sieci miejskiej kominek'
    ],
    "gas": [
        'gazowe', 'c o gazowe', 'ogrzewanie na gaz miejski', 'c o gazowe inne', 'c o gazowe piec', 'własne gazowe', 'gazowe budynkowe'
    ],
    "individual": [
        'własne', 'co własne', 'c o własne', 'własne dla budynku', 'co z własnej kotłowni', 'c o z własnej kotłowni', 'c o lokalne', 'boiler room', 'z własnej kotłowni'
    ],
    "electrical": [
        'elektryczne', 'ogrzewanie elektryczne', 'c o elektryczne'
    ],
    "heat_pump": [
        'pompa ciepła', 'piec pompa ciepła'
    ],
    "fireplace": [
        'kominek'
    ],
    "stove": [
        'piec', 'tiled stove'
    ],
    "other": [
        'inne', 'zroznicowane', 'ekologiczne', 'eta owe', 'eta?owe'
    ],
    "oil": [
        'olej opałowy'
    ],
    "underfloor": [
        'podłogowe'
    ],
    "UNKNOWN": [
        'none'
    ]
}


def replace_values_with_keys(portal_data_objects, column_name, replace_dict):
    for obj in portal_data_objects:
        for key, terms in replace_dict.items():
            for term in terms:
                obj.df[column_name] = obj.df[column_name].replace(term, key)

for data_frame in portal_data_objects:
    data_frame.create_nan_column(['heating_type'])

replace_values_with_keys(portal_data_objects, 'heating_type', heating_types_dict)

morizon.df['heating_type'] = morizon.df['heating_type'].apply(lambda x: 'gas' if 'gaz' in x else x)
morizon.df['heating_type'] = morizon.df['heating_type'].apply(lambda x: 'urban' if 'c.o.' in x else x)

# %%
generate_column_value_dataframe(portal_data_objects, 'heating_type')
# Out:
# heating_type
# urban         56.1%
# UNKNOWN       36.4%
# gas            3.6%
# other          1.9%
# individual     1.1%
# central        0.6%
# electrical     0.3%
# heat_pump      0.1%
# stove          0.0%
# oil            0.0%
# fireplace      0.0%
# underfloor     0.0%
# Name: proportion, dtype: object

# %%
heating_normilize_dict = {
    'other': ['heat_pump', 'stove', 'tiled_stove', 'oil', 'fireplace', 'underfloor']
}

replace_values_with_keys(portal_data_objects, 'heating_type', heating_normilize_dict)
generate_column_value_dataframe(portal_data_objects, 'heating_type')
# Out:
# heating_type
# urban         56.1%
# UNKNOWN       36.4%
# gas            3.6%
# other          2.0%
# individual     1.1%
# central        0.6%
# electrical     0.3%
# Name: proportion, dtype: object

# %% [markdown]
# ##### kitchen_type -> DROP COLUMN
# Morizon: 75% NONE
# Otodom: 81%

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['kitchen_type'])
# Out:
# UNIQUE VALUES FOR 'morizon_kitchen_type': 10
# Percentage of 'none' values for 'morizon_kitchen_type': 75.94%
# UNIQUE VALUES FOR 'otodom_kitchen_type': 2
# Percentage of 'none' values for 'otodom_kitchen_type': 81.06%
# Unique values in 'otodom_kitchen_type': ['separate kitchen' 'none']
# UNIQUE VALUES FOR 'no_kitchen_type': 21
# Percentage of 'none' values for 'no_kitchen_type': 21.13%
#      morizon_kitchen_type otodom_kitchen_type  \
# 7182                 none    separate kitchen
# 6360              otwarta                none
# 6108                 none                none
# 5541                 none                none
# 1973            oddzielna                none
# 5009                 none                none
#
#                          no_kitchen_type
# 7182                                 NaN
# 6360  aneks kuchenny z oknem w zabudowie
# 6108                             z oknem
# 5541                             z oknem
# 1973                                none
# 5009                           oddzielna

# %% [markdown]
# #####  material -> DROP COLUMN
#
# - Morizon: 66% of NONE, 66 cases
# - Otodom:  50% of NONE
# - NO: False values

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['material'])
# Out:
# UNIQUE VALUES FOR 'morizon_material': 51
# Percentage of 'none' values for 'morizon_material': 66.65%
# UNIQUE VALUES FOR 'otodom_material': 11
# Percentage of 'none' values for 'otodom_material': 50.33%
# UNIQUE VALUES FOR 'no_material': 5
# Percentage of 'none' values for 'no_material': 0.00%
# Unique values in 'no_material': ['false' 'tradycyjna cegła' 'nowa technologia' 'wielka płyta' nan]
#            morizon_material otodom_material       no_material
# 1231                   none            none             false
# 1965  konstrukcja zelbetowa  concrete plate             false
# 6367                   none           brick  tradycyjna cegła
# 479                mieszany            none             false
# 4583                 rama h            none             false
# 1554                   none            none             false

# %% [markdown]
# ##### property_type -> DROP COLUMN
# all_platforms == mieszkanie

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['property_type'])
# Out:
# UNIQUE VALUES FOR 'morizon_property_type': 1
# Percentage of 'none' values for 'morizon_property_type': 0.00%
# Unique values in 'morizon_property_type': ['mieszkanie']
# UNIQUE VALUES FOR 'otodom_property_type': 1
# Percentage of 'none' values for 'otodom_property_type': 0.00%
# Unique values in 'otodom_property_type': ['mieszkanie']
# UNIQUE VALUES FOR 'no_property_type': 2
# Percentage of 'none' values for 'no_property_type': 0.00%
# Unique values in 'no_property_type': ['mieszkanie' nan]
#      morizon_property_type otodom_property_type no_property_type
# 3374            mieszkanie           mieszkanie       mieszkanie
# 2598            mieszkanie           mieszkanie       mieszkanie
# 676             mieszkanie           mieszkanie       mieszkanie
# 867             mieszkanie           mieszkanie       mieszkanie
# 2329            mieszkanie           mieszkanie       mieszkanie
# 6808            mieszkanie           mieszkanie       mieszkanie

# %%
#DROP COLUMNS
for data_frame in portal_data_objects:
    data_frame.delete_columns(['kitchen_type', 'material', 'property_type'])

# %% [markdown]
# ### Process similar column by tematical group

# %%
def add_unmatched_columns_to_dict(existing_columns, **dataframes):
    columns_dict = {}
    
    for platform, df in dataframes.items():
        columns_dict[platform] = []
        for col in df.columns:
            if col not in existing_columns:
                columns_dict[platform].append(col)

    return columns_dict

unmatched_columns_names = add_unmatched_columns_to_dict(similar_column_names, morizon=morizon.df, otodom=otodom.df, no=no.df)

# %%
for platform, columns in unmatched_columns_names.items():
    filtered_columns = [col for col in columns if '_nan' not in col]
    print(f"{platform}: {sorted(filtered_columns)}")
# Out:
# morizon: ['balcony', 'bath_with_wc', 'building_type', 'building_year', 'city', 'description', 'electricity', 'gas', 'id', 'market_type', 'platform', 'prec_adress', 'primery_market', 'row_price', 'transaction_type', 'water']
# otodom: ['balcony/loggia', 'building_type', 'building_year', 'city', 'date_added', 'date_update', 'id', 'id_realestateagency', 'market_type', 'ownership_form', 'portal_name', 'price', 'property_rent', 'security', 'street', 'windows']
# no: ['balcony/loggia', 'bulding_type', 'bulding_year', 'date_added', 'date_update', 'electricity', 'gas', 'height', 'id_portal', 'id_realestateagency', 'makret_type', 'ownership_form', 'portal_name', 'prec_adress', 'price', 'property_rent', 'saperate_wc', 'security', 'standard', 'street', 'town/city', 'water', 'windows']

# %% [markdown]
# ### Raname columns:
# - Morizon:
#     - platform: portal_name
#     - row_price: price
#     - prec_adress': 'street'
# - Otodom:
#     - balcony/loggia: balcony
# - NO:
#     - balcony/loggia: balcony
#     - bulding_type: building_type
#     - bulding_year: building_year
#     - town/city: city
#     - id_portal: id
#     - makret_type: market_type

# %%
rename_dict = {
    'morizon': {
        'platform': 'portal_name',
        'row_price': 'price',
        'prec_adress': 'street' 
    },
    'otodom': {
        'balcony/loggia': 'balcony',
    },
    'no': {
        'balcony/loggia': 'balcony',
        'bulding_type': 'building_type',
        'bulding_year': 'building_year',
        'town/city': 'city',
        'id_portal': 'id',
        'makret_type': 'market_type',
    }
}

def rename_columns(platform, df, rename_dict):
    if platform in rename_dict:
        df.rename(columns=rename_dict[platform], inplace=True)
    return df

rename_columns('morizon', morizon.df, rename_dict)
rename_columns('otodom', otodom.df, rename_dict)
rename_columns('no', no.df, rename_dict)
# Out:
#      balcony  basement            building_type building_year date_added  \
# 0       True         1          blok mieszkalny          1980       none
# 1       True         0          blok mieszkalny          2000       none
# 2      False         1                kamienica          1911       none
# 3       True         0          apartamentowiec          2023       none
# 4       True         0  rok budowy: 2018, winda          2018       none
# ...      ...       ...                      ...           ...        ...
# 7036   False         1          blok mieszkalny          1950       none
# 7037   False         0          apartamentowiec          2019       none
# 7038    True         1          blok mieszkalny          2008       none
# 7040    True         0          blok mieszkalny          2017       none
# 7041    none         0                     none         False       none
#
#      date_update        district  electricity  elevator   gas  ...  \
# 0     17.03.2024         ursynow         True         0  none  ...
# 1     11.03.2024         mokotow         True         1  none  ...
# 2     18.03.2024     srodmiescie         True         0  none  ...
# 3     12.03.2024         mokotow         True         1  none  ...
# 4     17.03.2024         wilanow         True         1  none  ...
# ...          ...             ...          ...       ...   ...  ...
# 7036  17.03.2024     srodmiescie         True         0  none  ...
# 7037  04.03.2024         ursynow         True         1  none  ...
# 7038  23.02.2024  praga południe         True         0  none  ...
# 7040  28.02.2024       białołeka         True         1  none  ...
# 7041  09.03.2024         mokotow         True         0  none  ...
#
#                                                     url water     windows  \
# 0     https://warszawa.nieruchomosci-online.pl/miesz...  True  plastikowe
# 1     https://warszawa.nieruchomosci-online.pl/miesz...  True        none
# 2     https://warszawa.nieruchomosci-online.pl/miesz...  True  plastikowe
# 3     https://warszawa.nieruchomosci-online.pl/miesz...  True        none
# 4     https://warszawa.nieruchomosci-online.pl/miesz...  True        none
# ...                                                 ...   ...         ...
# 7036  https://warszawa.nieruchomosci-online.pl/miesz...  True  plastikowe
# 7037  https://warszawa.nieruchomosci-online.pl/miesz...  True  plastikowe
# 7038  https://warszawa.nieruchomosci-online.pl/miesz...  True  plastikowe
# 7040  https://warszawa.nieruchomosci-online.pl/miesz...  True  plastikowe
# 7041  https://warszawa.nieruchomosci-online.pl/miesz...  True        none
#
#      is_parking parking_nan  property_level_nan total_property_level_nan  \
# 0             1           0                   0                        0
# 1             1           0                   0                        0
# 2             0           1                   0                        0
# 3             0           1                   0                        0
# 4             1           0                   0                        0
# ...         ...         ...                 ...                      ...
# 7036          1           0                   0                        0
# 7037          1           0                   0                        0
# 7038          1           0                   0                        0
# 7040          1           0                   0                        0
# 7041          0           1                   0                        1
#
#      elevator_nan basement_nan heating_type_nan
# 0               0            0                0
# 1               0            0                1
# 2               0            0                0
# 3               0            0                0
# 4               0            0                1
# ...           ...          ...              ...
# 7036            0            0                1
# 7037            0            0                1
# 7038            0            0                0
# 7040            0            0                0
# 7041            0            1                1
#
# [6876 rows x 40 columns]

# %% [markdown]
# ### Drop columns (not match in all columns even in values specifications)

# %%
non_match_drop_columns = {
'morizon': [
    'description', 
    'bath_with_wc',
    "electricity", 
    "gas",
    "primery_market",
    "transaction_type",
    "water",
    ],
'otodom': [
    "date_added", 
    "date_update", 
    "id_realestateagency",
    "ownership_form",
    'property_rent',
    "security",
    'windows',
    ],
'no': [
    "date_added", 
    "date_update", 
    "electricity", 
    "gas", 
    "id_realestateagency",
    "ownership_form",
    "security",
    'water', 
    'windows',
    'saperate_wc', 
    'standard', 
    'height',
    'property_rent'
    ]
}

# Creating a new DataFrame that combines columns from different platforms with prefixes
# Sorting columns alphabetically without considering the platform prefix
sorted_columns = sorted(
    (column for platform, columns in non_match_drop_columns.items() for column in columns),
    key=lambda x: x
)

combined_columns_df = pd.DataFrame({
    platform + '_' + column: objects_dataframes[platform][column]
    for platform, columns in non_match_drop_columns.items()
    for column in sorted_columns if column in columns and column in objects_dataframes[platform].columns
})

combined_columns_df
# Out:
#       morizon_bath_with_wc                                morizon_description  \
# 0                      0.0  Zapraszamy do zapoznania się z naszą ofertą sp...
# 1                      0.0  Mam przyjemność zaprezentować Państwu wyjątkow...
# 2                      0.0  Mam przyjemność zaprezentować Państwu wyjątkow...
# 3                      0.0  WE SPEAK ENGLISH – PLEASE DO NOT HESITATE TO C...
# 4                      0.0  1.Włącz lokalizator! Znajdź swoje wymarzone mi...
# ...                    ...                                                ...
# 11337                  NaN                                                NaN
# 11338                  NaN                                                NaN
# 11339                  NaN                                                NaN
# 11340                  NaN                                                NaN
# 11341                  NaN                                                NaN
#
#       morizon_electricity morizon_gas morizon_primery_market  \
# 0                     0.0         0.0              1 540 000
# 1                     0.0         0.0              1 560 000
# 2                     0.0         0.0              1 560 000
# 3                     1.0         0.0              1 650 000
# 4                     0.0         0.0              1 660 000
# ...                   ...         ...                    ...
# 11337                 NaN         NaN                    NaN
# 11338                 NaN         NaN                    NaN
# 11339                 NaN         NaN                    NaN
# 11340                 NaN         NaN                    NaN
# 11341                 NaN         NaN                    NaN
#
#       morizon_transaction_type morizon_water          otodom_date_added  \
# 0                     sprzedaz          none  2024-03-11T11:52:35+01:00
# 1                     sprzedaz          none  2024-03-11T12:41:55+01:00
# 2                     sprzedaz          none  2024-03-11T16:43:20+01:00
# 3                     sprzedaz          Woda  2024-03-13T11:35:07+01:00
# 4                     sprzedaz          none  2024-03-13T13:35:14+01:00
# ...                        ...           ...                        ...
# 11337                      NaN           NaN  2023-09-04T17:42:16+02:00
# 11338                      NaN           NaN  2024-02-19T13:19:42+01:00
# 11339                      NaN           NaN  2024-02-13T15:54:47+01:00
# 11340                      NaN           NaN  2024-02-25T08:13:45+01:00
# 11341                      NaN           NaN  2024-02-10T16:08:26+01:00
#
#               otodom_date_update otodom_id_realestateagency  ... no_gas  \
# 0      2024-03-15T19:32:12+01:00                  5077520.0  ...   none
# 1      2024-03-15T19:31:14+01:00                  5077520.0  ...   none
# 2      2024-03-15T19:29:27+01:00                  5077520.0  ...   none
# 3      2024-03-15T19:28:53+01:00                  5077520.0  ...   none
# 4      2024-03-15T19:26:48+01:00                  5077520.0  ...   none
# ...                          ...                        ...  ...    ...
# 11337  2024-03-15T20:10:00+01:00                       none  ...    NaN
# 11338  2024-03-05T13:24:47+01:00                       none  ...    NaN
# 11339  2024-03-04T15:58:39+01:00                       none  ...    NaN
# 11340  2024-02-25T09:33:03+01:00                       none  ...    NaN
# 11341  2024-02-10T17:33:03+01:00                       none  ...    NaN
#
#       no_height no_id_realestateagency           no_ownership_form  \
# 0          none        284958/3376/OMS                    własność
# 1          none        285188/3376/OMS                    własność
# 2          none        285124/3376/OMS                    własność
# 3          none           2422/464/OMS                    własność
# 4          none                1201419  własność, księga wieczysta
# ...         ...                    ...                         ...
# 11337       NaN                    NaN                         NaN
# 11338       NaN                    NaN                         NaN
# 11339       NaN                    NaN                         NaN
# 11340       NaN                    NaN                         NaN
# 11341       NaN                    NaN                         NaN
#
#       no_property_rent no_saperate_wc  \
# 0                    1            2.0
# 1                    1            1.0
# 2                  900            1.0
# 3                 none            1.0
# 4                    1           none
# ...                ...            ...
# 11337              NaN            NaN
# 11338              NaN            NaN
# 11339              NaN            NaN
# 11340              NaN            NaN
# 11341              NaN            NaN
#
#                                         no_security      no_standard no_water  \
# 0               domofon/wideofon, monitoring/kamery       do remontu     True
# 1      domofon/wideofon, monitoring/kamery, ochrona  wysoki standard     True
# 2      domofon/wideofon, monitoring/kamery, ochrona            dobry     True
# 3                        monitoring/kamery, ochrona  wysoki standard     True
# 4                                              none     bardzo dobry     True
# ...                                             ...              ...      ...
# 11337                                           NaN              NaN      NaN
# 11338                                           NaN              NaN      NaN
# 11339                                           NaN              NaN      NaN
# 11340                                           NaN              NaN      NaN
# 11341                                           NaN              NaN      NaN
#
#        no_windows
# 0      plastikowe
# 1            none
# 2      plastikowe
# 3            none
# 4            none
# ...           ...
# 11337         NaN
# 11338         NaN
# 11339         NaN
# 11340         NaN
# 11341         NaN
#
# [10731 rows x 27 columns]

# %% [markdown]
# ##### morizon.primery_market looks as if it contains the price of the property, and some of the rows have been removed - however, this was checked beforehand.
# The molivities of relating columns between rows have not been identified, they will all be removed

# %%
print('NONE / NaN count divided by lenght and percentege share in column')
for column in combined_columns_df.columns:
    none_count = combined_columns_df[column].isna().sum() + (combined_columns_df[column] == 'NONE').sum()
    total_length = len(combined_columns_df)
    print(f"{column}:\n {none_count}/{total_length} \t{(none_count/total_length)*100:.2f}%")
# Out:
# NONE / NaN count divided by lenght and percentege share in column
# morizon_bath_with_wc:
#  5928/10731 	55.24%
# morizon_description:
#  5928/10731 	55.24%
# morizon_electricity:
#  5928/10731 	55.24%
# morizon_gas:
#  5928/10731 	55.24%
# morizon_primery_market:
#  5928/10731 	55.24%
# morizon_transaction_type:
#  5928/10731 	55.24%
# morizon_water:
#  5928/10731 	55.24%
# otodom_date_added:
#  529/10731 	4.93%
# otodom_date_update:
#  529/10731 	4.93%
# otodom_id_realestateagency:
#  529/10731 	4.93%
# otodom_ownership_form:
#  529/10731 	4.93%
# otodom_property_rent:
#  529/10731 	4.93%
# otodom_security:
#  529/10731 	4.93%
# otodom_windows:
#  529/10731 	4.93%
# no_date_added:
#  3855/10731 	35.92%
# no_date_update:
#  3855/10731 	35.92%
# no_electricity:
#  3855/10731 	35.92%
# no_gas:
#  3855/10731 	35.92%
# no_height:
#  3855/10731 	35.92%
# no_id_realestateagency:
#  3855/10731 	35.92%
# no_ownership_form:
#  3855/10731 	35.92%
# no_property_rent:
#  3855/10731 	35.92%
# no_saperate_wc:
#  3855/10731 	35.92%
# no_security:
#  3855/10731 	35.92%
# no_standard:
#  3855/10731 	35.92%
# no_water:
#  3855/10731 	35.92%
# no_windows:
#  3855/10731 	35.92%

# %%
try:
    morizon.df.drop(columns=non_match_drop_columns['morizon'], inplace=True)
except KeyError as e:
    print(f"Failed to remove columns in morizon.df: {e}")

try:
    otodom.df.drop(columns=non_match_drop_columns['otodom'], inplace=True)
except KeyError as e:
    print(f"Failed to remove columns in otodom.df: {e}")

try:
    no.df.drop(columns=non_match_drop_columns['no'], inplace=True)
except KeyError as e:
    print(f"Failed to remove columns in no.df: {e}")

# %% [markdown]
# ### Renemed columns processing

# %%
similar_column_after_renamed = find_common_columns(morizon.df, otodom.df, no.df)

sorted_df_after_renamed = create_similar_dataframe(similar_column_after_renamed, morizon=morizon.df, otodom=otodom.df, no=no.df)

renamed_columns_without_similar = set(similar_column_after_renamed) - set(similar_column_names)
renamed_columns_without_similar = list(renamed_columns_without_similar)
renamed_columns_without_similar
# Out:
# ['building_year',
#  'building_type',
#  'elevator_nan',
#  'price',
#  'total_property_level_nan',
#  'market_type',
#  'balcony',
#  'city',
#  'heating_type_nan',
#  'id',
#  'property_level_nan',
#  'portal_name',
#  'street',
#  'basement_nan']

# %%
#PClean columns ones again
similar_columns_to_celean_text = [
 'balcony',
 'building_type',
 'building_year',
 'city',
 'market_type',
 'portal_name',
 'price',
 'street',
]

for portal_data_object in portal_data_objects:
    portal_data_object.clean_text_data(similar_columns_to_celean_text)
    if portal_data_object.df[similar_columns_to_celean_text].isnull().any().any():
        print("There are NaN values in the data - replaced with 'NONE")
        portal_data_object.complete_none()

# %%
renamed_dict = {
    #numerrical
    'price', #predicted value
    'building_year',

    #combine with district from previous section
    'street',

    'market_type',
    'building_type',
    'city',

    'balcony',
 
    'id',
    'portal_name',
    
    #nan flags
    'basement_nan',
    'elevator_nan',
    'heating_type_nan',
    'no_rooms_nan',
    'property_level_nan',
    'total_property_level_nan'
    }

# %%
sorted_df_with_prefix_renamed = create_similar_dataframe(similar_column_after_renamed, morizon=morizon.df, otodom=otodom.df, no=no.df)

# %% [markdown]
# ### Compare renamed columns

# %% [markdown]
# ##### market_type

# %%
display_sample_with_columns_list(sorted_df_with_prefix_renamed, ['market_type'])
# Out:
# UNIQUE VALUES FOR 'morizon_market_type': 2
# Percentage of 'none' values for 'morizon_market_type': 0.00%
# Unique values in 'morizon_market_type': ['wtorny' 'pierwotny']
# UNIQUE VALUES FOR 'otodom_market_type': 3
# Percentage of 'none' values for 'otodom_market_type': 0.00%
# Unique values in 'otodom_market_type': ['secondary' 'primary' nan]
# UNIQUE VALUES FOR 'no_market_type': 4
# Percentage of 'none' values for 'no_market_type': 9.60%
# Unique values in 'no_market_type': ['wtorny' 'none' nan 'pierwotny']
#      morizon_market_type otodom_market_type no_market_type
# 3620              wtorny          secondary            NaN
# 5089              wtorny          secondary         wtorny
# 6040              wtorny          secondary         wtorny
# 1374           pierwotny          secondary         wtorny
# 4073              wtorny          secondary         wtorny
# 5439              wtorny            primary         wtorny

# %%
# Displaying unique values for the 'morizon_market_type' column
morizon_unique_values = sorted_df_with_prefix_renamed['morizon_market_type'].unique()
print("Unique values for morizon_market_type:", morizon_unique_values)

# Displaying unique values for the 'otodom_market_type' column
otodom_unique_values = sorted_df_with_prefix_renamed['otodom_market_type'].unique()
print("Unique values for otodom_market_type:", otodom_unique_values)

# Displaying unique values for the 'no_market_type' column
no_unique_values = sorted_df_with_prefix_renamed['no_market_type'].unique()
print("Unique values for no_market_type:", no_unique_values)
# Out:
# Unique values for morizon_market_type: ['wtorny' 'pierwotny']
# Unique values for otodom_market_type: ['secondary' 'primary' nan]
# Unique values for no_market_type: ['wtorny' 'none' nan 'pierwotny']

# %%
rename_market_type_dict = {
    'pierwotny': 1,
    'primary': 1,
    'wtorny': 0,
    'wtórny': 0,
    'secondary': 0,
    'none':0
}

def change_column_values_with_dict(df, col_name, rename_dict, new_col_name=None):
    if col_name in df.columns:
        df[col_name] = df[col_name].map(rename_dict).fillna(df[col_name])
        if new_col_name:
            df.rename(columns={col_name: new_col_name}, inplace=True)
    else:
        print(f"Column '{col_name}' does not exist in DataFrame.")
    return df

for data_frame in portal_data_objects:
    data_frame.create_nan_column(['market_type'])
    data_frame.df.rename(columns={'market_type_nan': 'is_primary_nan'}, inplace=True)
    change_column_values_with_dict(data_frame.df, 'market_type', rename_market_type_dict, 'is_primary')
    data_frame.unique_values(['is_primary', 'is_primary_nan'])
# Out:
# UNIQUE VALUES FOR 'is_primary': 2
# Percentage of 'none' values for 'is_primary': 0.00%
# Unique values in 'is_primary': [0 1]
# UNIQUE VALUES FOR 'is_primary_nan': 1
# Percentage of 'none' values for 'is_primary_nan': 0.00%
# Unique values in 'is_primary_nan': [0]
# UNIQUE VALUES FOR 'is_primary': 2
# Percentage of 'none' values for 'is_primary': 0.00%
# Unique values in 'is_primary': [0 1]
# UNIQUE VALUES FOR 'is_primary_nan': 1
# Percentage of 'none' values for 'is_primary_nan': 0.00%
# Unique values in 'is_primary_nan': [0]
# UNIQUE VALUES FOR 'is_primary': 2
# Percentage of 'none' values for 'is_primary': 0.00%
# Unique values in 'is_primary': [0 1]
# UNIQUE VALUES FOR 'is_primary_nan': 2
# Percentage of 'none' values for 'is_primary_nan': 0.00%
# Unique values in 'is_primary_nan': [0 1]

# %% [markdown]
# #### PRICE

# %%
display_sample_with_columns_list(sorted_df_with_prefix_renamed, ['price'])
# Out:
# UNIQUE VALUES FOR 'morizon_price': 1371
# Percentage of 'none' values for 'morizon_price': 0.00%
# UNIQUE VALUES FOR 'otodom_price': 1507
# Percentage of 'none' values for 'otodom_price': 0.00%
# UNIQUE VALUES FOR 'no_price': 1429
# Percentage of 'none' values for 'no_price': 0.00%
# UNIQUE VALUES FOR 'morizon_row_price_m2': 2682
# Percentage of 'none' values for 'morizon_row_price_m2': 0.00%
# UNIQUE VALUES FOR 'otodom_row_price_m2': 3020
# Percentage of 'none' values for 'otodom_row_price_m2': 0.00%
# UNIQUE VALUES FOR 'no_row_price_m2': 3026
# Percentage of 'none' values for 'no_row_price_m2': 0.00%
#      morizon_price  otodom_price   no_price  morizon_row_price_m2  \
# 2589     1 770 000      925000.0   750000.0                 22868
# 6321       402 868      729000.0  1970000.0                 15100
# 4615     2 800 000     1200000.0  1199000.0                 31059
# 6658       649 000      799000.0        NaN                 18543
# 1952     1 450 000      725000.0   719000.0                 22586
# 3556     1 020 000     1450000.0   680000.0                 17895
#
#       otodom_row_price_m2  no_row_price_m2
# 2589              18500.0          16505.0
# 6321              12972.0          30781.0
# 4615              17751.0          16813.0
# 6658              22507.0              NaN
# 1952              14646.0          12793.0
# 3556              34150.0          14782.0

# %%
otodom.df[(otodom.df['price'] == 'none')][['price', 'is_primary']]
# Out:
# Empty DataFrame
# Columns: [price, is_primary]
# Index: []

# %%
for data_frame in portal_data_objects:
    data_frame.df['price'] = data_frame.df['price'].astype(str).str.replace(' ', '').astype(float)
    print(data_frame.df.price.unique())
# Out:
# [1540000. 1560000. 1650000. ... 1236922. 1342814. 1361806.]
# [1290000. 1260000. 1283710. ... 5049000. 1479400. 9999999.]
# [1075000. 2110000. 1890000. ... 1062000.  549999.  678999.]

# %% [markdown]
# ### building_year -> int()

# %%
display_sample_with_columns_list(sorted_df_with_prefix_renamed, ['building_year'])
# Out:
# UNIQUE VALUES FOR 'morizon_building_year': 118
# Percentage of 'none' values for 'morizon_building_year': 5.79%
# UNIQUE VALUES FOR 'otodom_building_year': 133
# Percentage of 'none' values for 'otodom_building_year': 7.60%
# UNIQUE VALUES FOR 'no_building_year': 128
# Percentage of 'none' values for 'no_building_year': 0.00%
#      morizon_building_year otodom_building_year no_building_year
# 6378                2001.0                  NaN             2008
# 4335                1954.0                  NaN             2023
# 5264                1973.0               2019.0             2023
# 4104                1961.0                  NaN             2003
# 6526                2007.0               1957.0             2023
# 3529                1955.0               2022.0            false

# %%
no.convert_bool_to_int(['building_year'])

for data_frame in portal_data_objects:

    data_frame.create_nan_column(['building_year'])
    data_frame.df['building_year'] = data_frame.df['building_year'].apply(lambda x: 0 if isinstance(x, str) and 'none' in x else x)
    data_frame.df['building_year'] = data_frame.df['building_year'].astype(int)
    
    print(f"""
    {data_frame.df['building_year'].min()}
    {data_frame.df['building_year'].median()}
    {data_frame.df['building_year'].max()}
    """)

no.df.building_year.info
# Out:
#     0
#     2004.0
#     2026
#
#
#     0
#     2008.0
#     19392017
#
#
#     0
#     2003.0
#     19633
# <bound method Series.info of 0       1980
# 1       2000
# 2       1911
# 3       2023
# 4       2018
#         ...
# 7036    1950
# 7037    2019
# 7038    2008
# 7040    2017
# 7041       0
# Name: building_year, Length: 6876, dtype: int64>

# %%
min_builging_year = 1890
max_building_year = 2025


for data_frame in portal_data_objects:
    print("Smallest values of building_year (from 15. index): ", sorted(data_frame.df['building_year'].unique())[0:15])
    print("Largest values of building_year (from 20. index): ", sorted(data_frame.df['building_year'].unique(), reverse=True)[0:15])
    print(f"Percentage of observations with 'building_year' < {min_builging_year}: {round((data_frame.df['building_year'] < min_builging_year).sum() / len(data_frame.df) * 100, 2)}%")
    print(f"Percentage of observations with 'building_year' > {max_building_year}: {round((data_frame.df['building_year'] > max_building_year).sum() / len(data_frame.df) * 100, 2)}%")

    data_frame.df.loc[~data_frame.df['building_year'].between(min_builging_year, max_building_year), 'building_year'] = data_frame.df['building_year'].median()

    #check
    print("Smallest values of building_year after transformation: ", sorted(data_frame.df['building_year'].unique())[0:1])
    print("Largest values of building_year after transformation: ", sorted(data_frame.df['building_year'].unique(), reverse=True)[0:1])
    print("----")
# Out:
# Smallest values of building_year (from 15. index):  [0, 1860, 1870, 1878, 1890, 1894, 1897, 1900, 1901, 1904, 1905, 1906, 1908, 1910, 1911]
# Largest values of building_year (from 20. index):  [2026, 2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]
# Percentage of observations with 'building_year' < 1890: 5.91%
# Percentage of observations with 'building_year' > 2025: 0.02%
# Smallest values of building_year after transformation:  [1890]
# Largest values of building_year after transformation:  [2025]
# ----
# Smallest values of building_year (from 15. index):  [0, 1, 19, 60, 200, 210, 1505, 1822, 1830, 1836, 1838, 1860, 1869, 1870, 1875]
# Largest values of building_year (from 20. index):  [19392017, 20024, 19881, 19861, 19633, 11954, 2026, 2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018]
# Percentage of observations with 'building_year' < 1890: 9.04%
# Percentage of observations with 'building_year' > 2025: 0.65%
# Smallest values of building_year after transformation:  [1890]
# Largest values of building_year after transformation:  [2025]
# ----
# Smallest values of building_year (from 15. index):  [0, 19, 1830, 1836, 1838, 1860, 1869, 1875, 1878, 1890, 1894, 1895, 1897, 1900, 1901]
# Largest values of building_year (from 20. index):  [19633, 2026, 2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]
# Percentage of observations with 'building_year' < 1890: 7.52%
# Percentage of observations with 'building_year' > 2025: 0.15%
# Smallest values of building_year after transformation:  [1890]
# Largest values of building_year after transformation:  [2025]
# ----

# %% [markdown]
# ### Combine columns related to district:
# - street
# - prec_adress
# - district

# %% [markdown]
# ##### district
# - Not always same district -> additional streets or subdistricts
# - Potenialy 485 cases (NO)

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['district'])
# Out:
# UNIQUE VALUES FOR 'morizon_district': 86
# Percentage of 'none' values for 'morizon_district': 0.62%
# UNIQUE VALUES FOR 'otodom_district': 136
# Percentage of 'none' values for 'otodom_district': 3.28%
# UNIQUE VALUES FOR 'no_district': 485
# Percentage of 'none' values for 'no_district': 1.89%
#      morizon_district otodom_district   no_district
# 1117           bemowo         bielany       mokotow
# 6786          mokotow  praga południe     białołeka
# 50            mokotow        wygledow       wilanow
# 1620          ursynow         imielin        słuzew
# 5413   praga poludnie         mokotow  praga połnoc
# 4995             none         mokotow        ochota

# %%
district_columns = ['morizon_district', 'otodom_district', 'no_district']

def preprocess_string_columns(data_frame, column_names):

    for column in column_names:
        if column in data_frame.columns:
            # Adding handling of NaN values before processing text and skipping 'NONE' values without changing their value
            modified_data = data_frame[column].apply(lambda x: unidecode.unidecode(x.lower().strip()) if isinstance(x, str) and x != 'none' else x)
            data_frame[column] = modified_data

# Performing preprocess_string_columns on sorted_df_with_prefix
preprocess_string_columns(sorted_df_with_prefix, district_columns)

# %%
# Function to replace subdistricts with main districts
def replace_subdistricts_with_districts(data_frame, column_name):
    # Creating a new column with replaced values based on the dictionary
    def map_districts(subdistrict):
        for district, subdistricts in districts_subdistricts_dict.items():
            if subdistrict in subdistricts:
                return district
        return subdistrict

    data_frame[column_name + '_norm'] = data_frame[column_name].apply(map_districts)

# Calling the function for the appropriate columns in the DataFrame
replace_subdistricts_with_districts(sorted_df_with_prefix, 'morizon_district')
replace_subdistricts_with_districts(sorted_df_with_prefix, 'otodom_district')
replace_subdistricts_with_districts(sorted_df_with_prefix, 'no_district')

display_sample_with_columns_list(sorted_df_with_prefix, ['district_norm'])
# Out:
# UNIQUE VALUES FOR 'morizon_district_norm': 84
# Percentage of 'none' values for 'morizon_district_norm': 0.62%
# UNIQUE VALUES FOR 'otodom_district_norm': 29
# Percentage of 'none' values for 'otodom_district_norm': 3.28%
# UNIQUE VALUES FOR 'no_district_norm': 358
# Percentage of 'none' values for 'no_district_norm': 1.89%
#      morizon_district_norm otodom_district_norm no_district_norm
# 1705             bialoleka                wawer          mokotow
# 1006                bemowo               wesola          mokotow
# 1095                 ursus                 wola        bialoleka
# 6228               bielany            bialoleka        rembertow
# 6447              targowek               wesola          ursynow
# 3701                wlochy              mokotow          mokotow

# %%
display_sample_with_columns_list(sorted_df_with_prefix, ['district'])
# Out:
# UNIQUE VALUES FOR 'morizon_district': 86
# Percentage of 'none' values for 'morizon_district': 0.62%
# UNIQUE VALUES FOR 'otodom_district': 136
# Percentage of 'none' values for 'otodom_district': 3.28%
# UNIQUE VALUES FOR 'no_district': 485
# Percentage of 'none' values for 'no_district': 1.89%
# UNIQUE VALUES FOR 'morizon_district_norm': 84
# Percentage of 'none' values for 'morizon_district_norm': 0.62%
# UNIQUE VALUES FOR 'otodom_district_norm': 29
# Percentage of 'none' values for 'otodom_district_norm': 3.28%
# UNIQUE VALUES FOR 'no_district_norm': 358
# Percentage of 'none' values for 'no_district_norm': 1.89%
#      morizon_district otodom_district  no_district morizon_district_norm  \
# 2412            ursus         bielany  srodmiescie                 ursus
# 1695     praga polnoc       rembertow       bemowo          praga polnoc
# 4334          mokotow          goclaw      mokotow               mokotow
# 3663          bielany         mokotow      ursynow               bielany
# 5846            wawer     srodmiescie      bielany                 wawer
# 649            wlochy         mokotow    tarchomin                wlochy
#
#      otodom_district_norm no_district_norm
# 2412              bielany      srodmiescie
# 1695            rembertow           bemowo
# 4334       praga poludnie          mokotow
# 3663              mokotow          ursynow
# 5846          srodmiescie          bielany
# 649               mokotow        bialoleka

# %%
# Counting occurrences of values in columns *_district_norm that are not in the dictionary
columns_to_check = ['morizon_district_norm', 'otodom_district_norm', 'no_district_norm']
undocumented_district_counts = {}

# Getting keys from the dictionary
dict_keys = set(districts_subdistricts_dict.keys())

for column in columns_to_check:
    for value in sorted_df_with_prefix[column]:
        if value not in dict_keys:
            if value in undocumented_district_counts:
                undocumented_district_counts[value] += 1
            else:
                undocumented_district_counts[value] = 1

# Displaying results
print("Number of occurrences of values not in the dictionary:")
print(sorted(undocumented_district_counts.items(), key=lambda item: item[1], reverse=True))
# Out:
# Number of occurrences of values not in the dictionary:
# [('none', 423), (nan, 266), ('praga', 69), ('zakroczym', 23), ('chelmzynska', 9), ('marymont', 9), ('koszyki', 9), ('ostrobramska', 8), ('potok', 8), ('aleja komisji edukacji narodowej', 7), ('ludwiki', 6), ('zielona', 6), ('wiktoryn', 6), ('aleja wilanowska', 6), ('kapucka', 6), ('domaniewska', 5), ('pulawska', 5), ('odynca', 5), ('kolejowa', 5), ('optykow', 5), ('gorczewska', 4), ('bagno', 4), ('bukowinska', 4), ('grzybowska', 4), ('szeligowska', 4), ('sewastopolska', 4), ('korotynskiego', 4), ('gornoslaska', 4), ('nowodworska', 4), ('harfowa', 4), ('wilhelma', 3), ('guminska', 3), ('fasolowa', 3), ('piekna', 3), ('malborska', 3), ('zlota', 3), ('sulejkowska', 3), ('leona', 3), ('konstruktorska', 3), ('czerniakowska', 3), ('lipska', 3), ('szczesliwicka', 3), ('wlodarzewska', 3), ('grochowska', 3), ('sielecka', 3), ('talarowa', 3), ('dickensa', 3), ('paryska', 3), ('pory', 3), ('aleja jerzego waszyngtona', 3), ('aleja niepodleglosci', 3), ('fabryczna', 3), ('aleja stanow zjednoczonych', 3), ('kokoryczki', 3), ('saska', 3), ('kotsisa', 3), ('wygoda', 3), ('plac mirowski', 3), ('natalinska', 3), ('fabryczna 6', 3), ('kosynierow', 3), ('anyzkowa 2', 3), ('bledna', 3), ('trzeciakowskich', 3), ('tworki', 3), ('pilsudskiego 6', 3), ('jednosci', 3), ('stara iwiczna', 3), ('jozefa pilsudskiego', 3), ('olenki 12', 3), ('thomasa alva edisona 1', 3), ('labiszynska', 2), ('jagiellonska', 2), ('wilcza', 2), ('wiejska', 2), ('turmoncka', 2), ('mochtynska', 2), ('stawki', 2), ('swietojerska', 2), ('heroldow', 2), ('ryzowa', 2), ('odkryta', 2), ('jana', 2), ('bartycka', 2), ('lubiniecka', 2), ('raclawicka', 2), ('radzyminska', 2), ('boleslawa', 2), ('siedlecka', 2), ('klobucka', 2), ('sulkowicka', 2), ('winorosli', 2), ('krolikarnia', 2), ('gory skierdowskie', 2), ('kaliszowka', 2), ('klinkierowa', 2), ('liliowa', 2), ('rzepichy', 2), ('balkonowa', 2), ('pereca', 2), ('grojecka', 2), ('lukowska', 2), ('maltanska', 2), ('palestynska', 2), ('konstancinska', 2), ('krasiczynska', 2), ('nadwislanska', 2), ('rybaltow', 2), ('wyszogrodzka', 2), ('orkana', 2), ('krasnobrodzka', 2), ('dwernickiego', 2), ('pruszkowska', 2), ('alternatywy', 2), ('literacka', 2), ('herbsta', 2), ('iberyjska', 2), ('panny wodnej', 2), ('oginskiego', 2), ('lubelska', 2), ('kasprzaka', 2), ('dzielna', 2), ('kompasowa', 2), ('podolska', 2), ('jana kazimierza', 2), ('miedzynarodowa', 2), ('hieronima', 2), ('obrzezna', 2), ('czarnomorska', 2), ('szklanych domow', 2), ('lucka', 2), ('bogatynska', 2), ('przasnyska', 2), ('lochowska', 2), ('chodecka', 2), ('andersa', 2), ('maszynowa', 2), ('aleje jerozolimskie', 2), ('naleczowska', 2), ('srebrnych swierkow', 2), ('wankowicza', 2), ('kosciuszkowcow', 2), ('1 sierpnia', 2), ('chlodna', 2), ('majdanska', 2), ('warszawski swit', 2), ('modzelewskiego', 2), ('radzyminskiej', 1), ('plac', 1), ('szklanych', 1), ('dywizjonu', 1), ('piknikowa', 1), ('herbu', 1), ('targowa', 1), ('mariana', 1), ('artura', 1), ('obroncow', 1), ('bednarska', 1), ('daniszewska', 1), ('pilchowicka', 1), ('zeganska', 1), ('marcina', 1), ('okopowa', 1), ('ks', 1), ('foksal', 1), ('wojciecha', 1), ('przemyslowa', 1), ('niepodleglosci', 1), ('mordechaja', 1), ('andrzeja', 1), ('orlich', 1), ('przyczolek grochowski', 1), ('ruda', 1), ('latawiec', 1), ('kraski', 1), ('egejska', 1), ('abrahama', 1), ('zdziechowskiego', 1), ('lojewska', 1), ('bokserska', 1), ('grottgera', 1), ('jezewskiego', 1), ('aleja solidarnosci', 1), ('noskowskiego', 1), ('chmielna', 1), ('czerwonego krzyza', 1), ('motorowa', 1), ('puszczy solskiej', 1), ('etiudy rewolucyjnej', 1), ('aleja prymasa tysiaclecia', 1), ('lanciego', 1), ('anielewicza', 1), ('pszczynska', 1), ('aluzyjna', 1), ('wysockiego', 1), ('meander', 1), ('freta', 1), ('bonifraterska', 1), ('slominskiego', 1), ('bernardynska', 1), ('nowomiejska', 1), ('zupnicza', 1), ('marymoncka', 1), ('kolberga', 1), ('na uboczu', 1), ('niska', 1), ('kondratowicza', 1), ('skoroszewska', 1), ('kobielska', 1), ('kubanska', 1), ('przy torach', 1), ...

# %% [markdown]
# ##### Most of the remaining values are streets (including with addresses and in various forms, e.g., solidarnosci vs. solidarnosci avenue). Additionally, identified were:
# 'stara iwiczna' - outside of warsaw
# 'praga' - a problem with assigning the appropriate district
#
# Insofar as the results were to be improved in the future, it is molive to try and overwrite the streets with the names of the districts while normalizing them.

# %%
# Calculating the percentage of values that are not keys in the districts_subdistricts_dict
undocumented_district_percentages = {}
total_rows = len(sorted_df_with_prefix)
total_undocumented = 0
for column in columns_to_check:
    undocumented_count = sorted_df_with_prefix[column][~sorted_df_with_prefix[column].isin(dict_keys)].count()
    undocumented_district_percentages[column] = (undocumented_count / total_rows) * 100
    total_undocumented += undocumented_count

overall_percentage = (total_undocumented / (total_rows * len(columns_to_check))) * 100

print("Percentage of values not in the dictionary for each column:")
print({k: round(v, 2) for k, v in undocumented_district_percentages.items()})
print("Overall percentage of values not in the dictionary in all columns:", round(overall_percentage, 2), '%')
# Out:
# Percentage of values not in the dictionary for each column:
# {'morizon_district_norm': 2.18, 'otodom_district_norm': 4.5, 'no_district_norm': 9.3}
# Overall percentage of values not in the dictionary in all columns: 5.33 %

# %%
#Chcnge rest of values (5,5% of all rows) to uknnown
for data_frame in portal_data_objects:
    preprocess_string_columns(data_frame.df, ['district'])
    replace_subdistricts_with_districts(data_frame.df, 'district')
    data_frame.df['district_norm'] = data_frame.df['district_norm'].apply(lambda x: 'UNKNOWN' if x not in districts_subdistricts_dict.keys() else x)
    data_frame.unique_values(['district_norm'])
# Out:
# UNIQUE VALUES FOR 'district_norm': 19
# Percentage of 'none' values for 'district_norm': 0.00%
# UNIQUE VALUES FOR 'district_norm': 19
# Percentage of 'none' values for 'district_norm': 0.00%
# UNIQUE VALUES FOR 'district_norm': 19
# Percentage of 'none' values for 'district_norm': 0.00%

# %%
def create_dataframe_with_separeted_col(columns_list, **portal_data_objects):
    # Creating an empty DataFrame
    extracterd_columns_df = pd.DataFrame()
    
    # Iterating through each portal data object
    for portal_name, portal in portal_data_objects.items():
        # Checking which columns from the list are available in the DataFrame
        available_columns = [col for col in columns_list if col in portal.columns]
        # Creating a temporary DataFrame with available columns and adding a prefix
        temp_df = portal[available_columns].copy()
        temp_df.columns = [f"{portal_name}_{col}" for col in temp_df.columns]
        
        # Merging the DataFrame with the main DataFrame
        if extracterd_columns_df.empty:
            extracterd_columns_df = temp_df
        else:
            extracterd_columns_df = pd.merge(extracterd_columns_df, temp_df, how='outer', left_index=True, right_index=True)
    
    return extracterd_columns_df

localization_columns = ['district_norm', 'street', 'prec_adress']
seperated_localization_df = create_dataframe_with_separeted_col(columns_list=localization_columns, morizon=morizon.df, otodom=otodom.df, no=no.df)

# %%
display_sample_with_columns_list(seperated_localization_df, localization_columns)
# Out:
# UNIQUE VALUES FOR 'morizon_district_norm': 20
# Percentage of 'none' values for 'morizon_district_norm': 0.00%
# UNIQUE VALUES FOR 'morizon_street': 1249
# Percentage of 'none' values for 'morizon_street': 6.50%
# UNIQUE VALUES FOR 'otodom_district_norm': 20
# Percentage of 'none' values for 'otodom_district_norm': 0.00%
# UNIQUE VALUES FOR 'otodom_street': 1536
# Percentage of 'none' values for 'otodom_street': 24.97%
# UNIQUE VALUES FOR 'no_district_norm': 20
# Percentage of 'none' values for 'no_district_norm': 0.00%
# UNIQUE VALUES FOR 'no_street': 1353
# Percentage of 'none' values for 'no_street': 13.95%
# UNIQUE VALUES FOR 'no_prec_adress': 185
# Percentage of 'none' values for 'no_prec_adress': 61.32%
#      morizon_district_norm        morizon_street otodom_district_norm  \
# 7840                   NaN                   NaN               ochota
# 4861               wilanow     adama branickiego       praga poludnie
# 3897              zoliborz     ludwika rydygiera              bielany
# 4634                   NaN                   NaN                 wola
# 8634                   NaN                   NaN              mokotow
# 2801               mokotow  jana iii sobieskiego                ursus
#
#                     otodom_street no_district_norm no_street no_prec_adress
# 7840               ul łopuszanska              NaN       NaN            NaN
# 4861                ul witolinska          mokotow   wołoska           none
# 3897  ul zbigniewa romaszewskiego      srodmiescie     piwna           none
# 4634                   ul ludwiki          UNKNOWN      none           none
# 8634     ul stefana pienkowskiego              NaN       NaN            NaN
# 2801            ul posag 7 panien            wawer    czecha           none

# %% [markdown]
# ##### street and prec_adres (NO)

# %% [markdown]
# ##### street columns are non-standardized in many respects, and are also very numerous (about 1,500 per portal). As mentioned earlier, they should be standardized in the future based on the street dictionary. For the moment, they will be removed.
#
# prec_address in NO >60% NONE -> drop
#
# in connection with the normalization of the district in another column, it will be removed

# %%
#drop prec_adress and streets
localization_columns_to_drop = ['district', 'street', 'prec_adress']

for column in localization_columns_to_drop:
    for data_frame in portal_data_objects:
        if column in data_frame.df.columns:
            data_frame.delete_columns(column)

'district' in morizon.df.columns
# Out:
# False

# %% [markdown]
# #### building_type
# - morizon: 68% NONE values
# - no: if 'rok budowy' in  bulding_type (rok budowy: 1986) -> delete r'rok budowy: ****
# - no: delete winda
# -all platforms: unify dict to volues ['tenement', 'apartment', 'NONE', 'block', 'ribbon', 'house', 'other']

# %%
display_sample_with_columns_list(sorted_df_with_prefix_renamed, ['building_type'])
# Out:
# UNIQUE VALUES FOR 'morizon_building_type': 10
# Percentage of 'none' values for 'morizon_building_type': 52.72%
# UNIQUE VALUES FOR 'otodom_building_type': 8
# Percentage of 'none' values for 'otodom_building_type': 15.30%
# UNIQUE VALUES FOR 'no_building_type': 364
# Percentage of 'none' values for 'no_building_type': 3.39%
#      morizon_building_type otodom_building_type  \
# 5019                  blok             tenement
# 6643       apartamentowiec                  NaN
# 6501             kamienica                  NaN
# 3301       apartamentowiec                block
# 5516             kamienica            apartment
# 479        apartamentowiec                 none
#
#                                      no_building_type
# 5019                                  blok mieszkalny
# 6643                                        kamienica
# 6501                                  blok mieszkalny
# 3301  rok budowy 2006 blok w nowym budownictwie winda
# 5516                            rok budowy 2022 winda
# 479                                   blok mieszkalny

# %%
otodom_uniqe_btype = otodom.df['building_type'].unique()
otodom_uniqe_btype
# Out:
# array(['block', 'apartment', 'tenement', 'none', 'ribbon', 'house',
#        'infill', 'loft'], dtype=object)

# %% [markdown]
# ##### NO building_type

# %%
def extract_building_technic(building_type):
    if isinstance(building_type, str):
        technic = re.search(r'technika budowy: ([^,]+)', building_type)
        return technic.group(1) if technic else None
    return None

no_building_df = no.df['building_type'].astype(str).str.replace('winda', '', regex=False)
no_building_df = no_building_df.str.replace(r'rok budowy: \d{4}', '', regex=True)
no_building_df['building_technic'] = no_building_df.apply(extract_building_technic)
no_building_df = no_building_df.str.replace(r'technika budowy: [^,]+,?', '', regex=True)
no_building_df = no_building_df.apply(lambda x: 'block' if isinstance(x, str) and 'blok' in x else x)

print(no_building_df.unique())
# Out:
# ['block' 'kamienica' 'apartamentowiec' 'rok budowy 2018 '
#  'rok budowy 2000 ' 'rok budowy 2001 ' 'none' 'rok budowy 1973 '
#  'rok budowy 2024' 'rok budowy 2005' 'rok budowy 2023' 'dom wielorodzinny'
#  'rok budowy 2012 ' 'rok budowy 2024 ' 'rok budowy 2008' 'rok budowy 1928'
#  'rok budowy 1978 ' 'rok budowy 1994 ' 'rok budowy 2005 '
#  'dom wolnostojacy' 'rok budowy 1975'
#  'rok budowy 1980 technika budowy wielka płyta ' 'rok budowy 2000'
#  'rok budowy 2008 technika budowy tradycyjna cegła '
#  'rok budowy 2020 technika budowy tradycyjna cegła ' 'rok budowy 1962'
#  'rok budowy 2004' 'rok budowy 1998 technika budowy tradycyjna cegła'
#  'rok budowy 2002 ' 'rok budowy 1996 ' 'rok budowy 1976'
#  'rok budowy 1988 ' 'rok budowy 1995' 'rok budowy 2004 ' 'rok budowy 2021'
#  'rok budowy 2006 ' 'rok budowy 1982' 'rok budowy 2023 ' 'rok budowy 1998'
#  'rok budowy 1969 technika budowy tradycyjna cegła'
#  'rok budowy 2012 technika budowy tradycyjna cegła'
#  'apartamentowiec  dostosowany do osob niepełnosprawnych'
#  'apartamentowiec technika budowy tradycyjna cegła  dostosowany do osob niepełnosprawnych'
#  'rok budowy 2019' 'rok budowy 2022 technika budowy tradycyjna cegła '
#  'rok budowy 2022 ' 'rok budowy 1980'
#  'rok budowy 2013 technika budowy tradycyjna cegła'
#  'rok budowy 1975 technika budowy wielka płyta ' 'rok budowy 1969 '
#  'rok budowy 2003 ' 'rok budowy 2019 '
#  'rok budowy 1992  dostosowany do osob niepełnosprawnych'
#  'rok budowy 1994 technika budowy tradycyjna cegła' 'rok budowy 2020'
#  'rok budowy 1970 ' 'rok budowy 1950 technika budowy tradycyjna cegła'
#  'rok budowy 1961' 'rok budowy 1921' 'rok budowy 2009'
#  'rok budowy 2010 technika budowy tradycyjna cegła ' 'rok budowy 1971 '
#  'rok budowy 1950' 'rok budowy 2017' 'rok budowy 1976 ' 'rok budowy 2025'
#  'rok budowy 1959 technika budowy tradycyjna cegła'
#  'rok budowy 1935 technika budowy tradycyjna cegła'
#  'rok budowy 1936 technika budowy tradycyjna cegła' 'rok budowy 1966'
#  'rok budowy 1960 ' 'rok budowy 1997 '
#  'rok budowy 1969 technika budowy wielka płyta'
#  'rok budowy 2007  dostosowany do osob niepełnosprawnych'
#  'rok budowy 2002' 'rok budowy 1952 technika budowy tradycyjna cegła '
#  'rok budowy 1974 technika budowy wielka płyta' 'rok budowy 1955'
#  'rok budowy 2013' 'rok budowy 2002 technika budowy tradycyjna cegła '
#  'rok budowy 1930' 'rok budowy 2010 '
#  'apartamentowiec technika budowy tradycyjna cegła ' 'rok budowy 1972'
#  'rok budowy 1999' 'rok budowy 2009 ' 'rok budowy 1987' 'rok budowy 2017 '
#  'rok budowy 1939' 'rok budowy 1976 technika budowy wielka płyta'
#  'rok budowy 1956' 'rok budowy 1980 technika budowy tradycyjna cegła'
#  'rok budowy 1967 technika budowy wielka płyta'
#  'rok budowy 1970 technika budowy tradycyjna cegła' 'rok budowy 1980 '
#  'rok budowy 1981 ' 'rok budowy 1965' 'rok budowy 1970'
#  'rok budowy 2023 technika budowy tradycyjna cegła' 'rok budowy 2018'
#  'rok budowy 2015' 'rok budowy 2026 technika budowy tradycyjna cegła '
#  'rok budowy 2025 technika budowy tradycyjna cegła '
#  'rok budowy 1956 technika budowy tradycyjna cegła'
#  'rok budowy 2016 technika budowy tradycyjna cegła  dostosowany do osob niepełnosprawnych'
#  'rok budowy 1932 ' 'rok budowy 1965 '
#  'rok budowy 2001 technika budowy tradycyjna cegła' 'apartamentowiec '
#  'rok budowy 1977' 'rok budowy 1972 ' 'rok budowy 1960' 'rok budowy 1978'
#  'rok budowy 1967' 'rok budowy 1969' 'rok budowy 1973' 'rok budowy 2006'
#  'rok budowy 1961 ' 'rok budowy 2016' 'rok budowy 1981'
#  'rok budowy 2011 technika budowy tradycyjna cegła '
#  'kamienica technika budowy tradycyjna cegła'
#  'rok budowy 2024  dostosowany do osob niepełnosprawnych'
#  'rok budowy 1966 ' 'rok budowy 2021 '
#  'rok budowy 1996 technika budowy tradycyjna cegła'
#  'rok budowy 1999 technika budowy tradycyjna cegła' 'rok budowy 1987 '
#  'rok budowy 2025 ' 'rok budowy 1993' 'rok budowy 1990'
#  'rok budowy 2023 technika budowy tradycyjna cegła ' 'rok budowy 1990 '
#  'rok budowy 2009 technika budowy tradycyjna cegła'
#  'rok budowy 1967 technika budowy tradycyjna cegła'
#  'rok budowy 1978 technika budowy wielka płyta' 'rok budowy 2013 '
#  'rok budowy 1984 technika budowy wielka płyta '
#  'rok budowy 1939 technika budowy tradycyjna cegła'
#  'rok budowy 2005 technika budowy tradycyjna cegła ' 'rok budowy 1975 '
#  'rok budowy 1988' 'rok budowy 1953 technika budowy tradycyjna cegła'
#  'rok budowy 2007' 'rok budowy 1985' 'rok budowy 1936'
#  'rok budowy 1974 technika budowy wielka płyta ' 'rok budowy 2022'
#  'rok budowy 2004 technika budowy tradycyjna cegła ' 'rok budowy 1905'
#  'rok budowy 2003' 'rok budowy 2008 technika budowy tradycyjna cegła'
#  'rok budowy 1995 technika budowy tradycyjna cegła ' 'rok budowy 1954'
#  'rok budowy 2026  dostosowany do osob niepełnosprawnych'
#  'rok budowy 1860 technika budowy tradycyjna cegła'
#  'rok budowy 2000 technika budowy tradycyjna cegła' 'rok budowy 2011 '
#  'dom wielorodzinny ' 'rok budowy 1999 ' 'rok budowy 2020 '
#  'rok budowy 1968 ' 'rok budowy 1938' 'rok budowy 2015 '
#  'rok budowy 1982 technika budowy tradycyjna cegła ' 'rok budowy 2016 '
#  'rok budowy 1968' 'rok budowy 1963'
#  'rok budowy 1983 technika budowy wielka płyta'
#  'rok budowy 2003 technika budowy tradycyjna cegła '
#  'rok budowy 2019 technika budowy tradycyjna cegła' 'rok budowy 1998 '
#  'rok budowy 1952' 'rok budowy 1958 technika budowy tradycyjna cegła'
#  'rok budowy 1976 technika budowy tradycyjna cegła ' 'rok budowy 2001'
#  'rok budowy 2001 technika budowy tradycyjna cegła ' 'rezydencja'
#  'rok budowy 1977 technika budowy wielka płyta '
#  'rok budowy 1968 technika budowy wielka płyta'
#  'rok budowy 1987 technika budowy wielka płyta '
#  'rok budowy 1952 technika budowy tradycyjna cegła' 'rok budowy 1986 '
#  'rok budowy 1994 technika budowy tradycyjna cegła '
#  'rok budowy 1962 technika budowy tradycyjna cegła'
#  'kamienica technika budowy tradycyjna cegła ' 'rok budowy 1991 '
#  'rok budowy 1949 ' 'rok budowy 1996 technika budowy wielka płyta '
#  'rok budowy 1977 technika budowy wielka płyta'
#  'rok budowy 2022 technika budowy tradycyjna cegła' 'rok budowy 1997'
#  'rok budowy 1999 technika budowy tradycyjna cegła '
#  'rok budowy 1953 technika budowy tradycyjna cegła ' 'rok budowy 2014 '
#  'rok budowy 1964'
#  'rok budowy 2025  dostosowany do osob niepełnosprawnych'
#  'rok budowy 2005 technika budowy tradycyjna cegła' 'rok budowy 2010'
#  'rok budowy 1991 technika budowy tradycyjna cegła' 'rok budowy 1986'
#  'rok budowy 1997 technika budowy tradycyjna cegła'
#  'rok budowy 1965 technika budowy tradycyjna cegła' 'rok budowy 1913'
#  'rok budowy 1962 ' 'rok budowy 1985 '
#  'rok budowy 2007 technika budowy tradycyjna cegła ' 'rok budowy 1996'
#  'rok budowy 1929' 'rok budowy 1953'
#  'rok budowy 1930 technika budowy tradycyjna cegła '
#  'rok budowy 2012 technika budowy tradycyjna cegła '
#  'rok budowy 1970 technika budowy wielka płyta'
#  'rok budowy 1936 technika budowy tradycyjna cegła ' 'kamienica '
#  'rok budowy 1971' 'rok budowy 2006 technika budowy tradycyjna cegła'
#  'rok budowy 1991' 'rok budowy 2000 technika budowy tradycyjna cegła '
#  'apartamentowiec technika budowy tradycyjna cegła'
#  'apartamentowiec technika budowy nowa technologia ' 'rok budowy 2014'
#  'loft ' 'rok budowy 1984'
#  'rok budowy 1924 technika budowy tradycyjna cegła'
#  'rok budowy 2020 technika budowy tradycyjna cegła' 'rok budowy 1959'
#  'rok budowy 1974' 'rok budowy 1976 technika budowy wielka płyta '
#  'rok budowy 1979' 'rok budowy 1974 '
#  'rok budowy 1960 technika budowy tradycyjna cegła' 'rok budowy 1963 '
#  'rok budowy 1957' 'apartamentowiec dostosowany do osob niepełnosprawnych'
#  'rok budowy 2008 ' 'rok budowy 1993 technika budowy tradycyjna cegła '
#  'rok budowy 1973 technika budowy wielka płyta '
#  'rok budowy 1975 technika budowy wielka płyta' 'rok budowy 1957 '
#  'rok budowy 1900' 'rok budowy 1938 technika budowy tradycyjna cegła'
#  'rok budowy 2000  dostosowany do osob niepełnosprawnych'
#  'rok budowy 1999 technika budowy tradycyjna cegła dostosowany do osob niepełnosprawnych'
#  'rok budowy 1981 technika budowy wielka płyta '
#  'rok budowy 1937 technika budowy tradycyjna cegła' 'rok budowy 1984 '
#  'rok budowy 1983' 'rok budowy 1994' 'rok budowy 1838'
#  'rok budowy 1934 technika budowy tradycyjna cegła '
#  'rok budowy 1995 technika budowy tradycyjna cegła' 'rok budowy 1992'
#  'rok budowy 2024 technika budowy tradycyjna cegła'
#  'rok budowy 1929 technika budowy tradycyjna cegła'
#  'dom wielorodzinny technika budowy tradycyjna cegła' nan]

# %%
no_building_rename_dict = {
    'kamienica': 'tenement', 
    'apartamentowiec': 'apartment',  
    'apartament': 'apartment', 
    'dom wielorodzinny': 'tenement', 
    'dom wolnostojący': 'house', 
    'dom': 'house',
    'rezydencja': 'house',  
    'loft': 'loft',
}

def rename_building_type(building_type):
    if isinstance(building_type, str):
        parts = building_type.split(',')
        for part in parts:
            part = part.strip()
            if part in no_building_rename_dict:
                return no_building_rename_dict[part]
    return 'none'

no_building_df = no.df['building_type'].astype(str).apply(rename_building_type)
no.df['building_type'] = no_building_df

no.df['building_type'].unique()
# Out:
# array(['none', 'tenement', 'apartment', 'house'], dtype=object)

# %% [markdown]
# ##### Morizon building_type

# %%
morizon.df['building_type'].unique()
# Out:
# array(['kamienica', 'apartamentowiec', 'none', 'blok', 'segment', 'dom',
#        'szeregowy', 'wielorodzinny', 'inna', 'inny'], dtype=object)

# %%
morizon_building_rename_dict = {
    'apartamentowiec': 'apartment',
    'blok': 'block',
    'dom': 'house',
    'inna': 'other',
    'inny': 'other',
    'kamienica': 'tenement',
    'segment': 'ribbon',
    'szeregowy': 'ribbon',
    'wielorodzinny': 'house'
}

morizon.df['building_type'] = morizon.df['building_type'].map(morizon_building_rename_dict).fillna(morizon.df['building_type'])

# %%
morizon.df['building_type'].unique()
# Out:
# array(['tenement', 'apartment', 'none', 'block', 'ribbon', 'house',
#        'other'], dtype=object)

# %%
#refresh silimiar dataframe
sorted_df_after_rename = create_similar_dataframe(similar_column_after_renamed, morizon=morizon.df, otodom=otodom.df, no=no.df)

# %%
display_sample_with_columns_list(sorted_df_after_rename, ['building_type'])
# Out:
# UNIQUE VALUES FOR 'morizon_building_type': 7
# Percentage of 'none' values for 'morizon_building_type': 52.72%
# UNIQUE VALUES FOR 'otodom_building_type': 8
# Percentage of 'none' values for 'otodom_building_type': 15.30%
# UNIQUE VALUES FOR 'no_building_type': 5
# Percentage of 'none' values for 'no_building_type': 62.32%
# Unique values in 'no_building_type': ['none' 'tenement' 'apartment' nan 'house']
#      morizon_building_type otodom_building_type no_building_type
# 6784             apartment            apartment        apartment
# 5810                  none            apartment         tenement
# 5146                  none                block             none
# 3829                  none                  NaN             none
# 136                  block            apartment             none
# 5779                  none                  NaN        apartment

# %%
for data_frame in portal_data_objects:
    data_frame.create_nan_column(['building_type'])
    data_frame.df['building_type'] = data_frame.df['building_type'].apply(lambda x: 'UNKNOWN' if isinstance(x, str) and (x == 'none' or x == 'other') else x)
    data_frame.unique_values(['building_type'])
# Out:
# UNIQUE VALUES FOR 'building_type': 6
# Percentage of 'none' values for 'building_type': 0.00%
# UNIQUE VALUES FOR 'building_type': 8
# Percentage of 'none' values for 'building_type': 0.00%
# UNIQUE VALUES FOR 'building_type': 4
# Percentage of 'none' values for 'building_type': 0.00%
# Unique values in 'building_type': ['UNKNOWN' 'tenement' 'apartment' 'house']

# %% [markdown]
# #### city

# %%
city_column = ['morizon_city', 'otodom_city', 'no_city']

preprocess_string_columns(sorted_df_after_rename, city_column)

display_sample_with_columns_list(sorted_df_after_rename, ['city'])
# Out:
# UNIQUE VALUES FOR 'morizon_city': 2
# Percentage of 'none' values for 'morizon_city': 0.00%
# Unique values in 'morizon_city': ['warszawa' 'nowodworski']
# UNIQUE VALUES FOR 'otodom_city': 6
# Percentage of 'none' values for 'otodom_city': 0.00%
# UNIQUE VALUES FOR 'no_city': 7
# Percentage of 'none' values for 'no_city': 0.00%
#      morizon_city otodom_city   no_city
# 122      warszawa    warszawa  warszawa
# 5580     warszawa    warszawa  warszawa
# 59       warszawa    warszawa  warszawa
# 6953     warszawa    warszawa  warszawa
# 3917     warszawa    warszawa  warszawa
# 4952     warszawa    warszawa  warszawa

# %%
for data_frame in portal_data_objects:
    data_frame.unique_values(['city'])
    print(data_frame.df['city'].unique())
# Out:
# UNIQUE VALUES FOR 'city': 2
# Percentage of 'none' values for 'city': 0.00%
# Unique values in 'city': ['warszawa' 'nowodworski']
# ['warszawa' 'nowodworski']
# UNIQUE VALUES FOR 'city': 9
# Percentage of 'none' values for 'city': 0.00%
# ['warszawa' 'raszyn' 'zabki' 'macierzysz' 'piastow' 'marki' 'mysiadlo'
#  'bialoleka' 'dawidy bankowe']
# UNIQUE VALUES FOR 'city': 6
# Percentage of 'none' values for 'city': 0.00%
# ['warszawa' 'otrebusy' 'łomianki' 'piaseczno' 'janczewice'
#  'ozarow mazowiecki']

# %%
otodom.df['city'] = otodom.df['city'].apply(lambda x: 'warszawa' if isinstance(x, str) and 'bialoleka' in x else x)

# %%
for data_frame in portal_data_objects:
    data_frame.df.drop(data_frame.df[data_frame.df['city'] != 'warszawa'].index, inplace=True)
    data_frame.unique_values(['city'])
    #only one value in column - sure we have only warsaw offers
    data_frame.delete_columns(['city'])
# Out:
# UNIQUE VALUES FOR 'city': 1
# Percentage of 'none' values for 'city': 0.00%
# Unique values in 'city': ['warszawa']
# UNIQUE VALUES FOR 'city': 1
# Percentage of 'none' values for 'city': 0.00%
# Unique values in 'city': ['warszawa']
# UNIQUE VALUES FOR 'city': 1
# Percentage of 'none' values for 'city': 0.00%
# Unique values in 'city': ['warszawa']

# %% [markdown]
# #### balcony

# %%
display_sample_with_columns_list(sorted_df_after_rename, ['balcony'])
# Out:
# UNIQUE VALUES FOR 'morizon_balcony': 2
# Percentage of 'none' values for 'morizon_balcony': 0.00%
# Unique values in 'morizon_balcony': [0. 1.]
# UNIQUE VALUES FOR 'otodom_balcony': 3
# Percentage of 'none' values for 'otodom_balcony': 4.81%
# Unique values in 'otodom_balcony': [1.0 'none' nan]
# UNIQUE VALUES FOR 'no_balcony': 4
# Percentage of 'none' values for 'no_balcony': 21.84%
# Unique values in 'no_balcony': [True False 'none' nan]
#       morizon_balcony otodom_balcony no_balcony
# 2711              1.0            1.0       True
# 3730              1.0            1.0      False
# 4044              0.0            1.0       True
# 105               1.0            1.0       True
# 4282              0.0            NaN       True
# 1604              0.0            1.0       none

# %%
for data_frame in portal_data_objects:
    data_frame.create_nan_column(['balcony'])
    data_frame.replace_none_with_binary(['balcony'])
    if data_frame == no:
        data_frame.convert_bool_to_int(['balcony'])
    data_frame.unique_values(['balcony'])
# Out:
# UNIQUE VALUES FOR 'balcony': 2
# Percentage of 'none' values for 'balcony': 0.00%
# Unique values in 'balcony': [0. 1.]
# UNIQUE VALUES FOR 'balcony': 2
# Percentage of 'none' values for 'balcony': 0.00%
# Unique values in 'balcony': [1. 0.]
# UNIQUE VALUES FOR 'balcony': 2
# Percentage of 'none' values for 'balcony': 0.00%
# Unique values in 'balcony': [1 0]

# %% [markdown]
# #### id

# %%
display_sample_with_columns_list(sorted_df_after_rename, ['id', 'url'])
# Out:
# UNIQUE VALUES FOR 'morizon_id': 4501
# Percentage of 'none' values for 'morizon_id': 0.00%
# UNIQUE VALUES FOR 'otodom_id': 4418
# Percentage of 'none' values for 'otodom_id': 0.00%
# UNIQUE VALUES FOR 'no_id': 4494
# Percentage of 'none' values for 'no_id': 0.00%
# UNIQUE VALUES FOR 'morizon_url': 4501
# Percentage of 'none' values for 'morizon_url': 0.00%
# UNIQUE VALUES FOR 'otodom_url': 4418
# Percentage of 'none' values for 'otodom_url': 0.00%
# UNIQUE VALUES FOR 'no_url': 4494
# Percentage of 'none' values for 'no_url': 0.00%
#          morizon_id   otodom_id     no_id  \
# 4967  mzn2043416756  65186089.0  24767203
# 6906  mzn2043480003  65131321.0  24711628
# 85    mzn2043368944  65223780.0  24731204
# 316   mzn2043366512  65162448.0  24726651
# 4499  mzn2043229905  65191942.0  24805301
# 1676  mzn2042729551  64743400.0  24521557
#
#                                             morizon_url  \
# 4967  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 6906  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 85    https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 316   https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 4499  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 1676  https://www.morizon.pl/oferta/sprzedaz-mieszka...
#
#                                              otodom_url  \
# 4967                 3-pokoje-mokotow-2024-iiiq-ID4pwSx
# 6906  sprzedam-mieszkanie-na-atrakcyjnym-bemowie-ID4...
# 85    kawalerka-metro-wilanowska-balkon-do-wprowadz-...
# 316   okazja-dwa-tarasy-przestrzenne-3-pokoje-kabaty...
# 4499  3-pokojowe-mieszkanie-w-dobrej-lokalizacji-ID4...
# 1676    komfortowy-przestronny-jasny-apartament-ID4nEIo
#
#                                                  no_url
# 4967  https://warszawa.nieruchomosci-online.pl/miesz...
# 6906  https://warszawa.nieruchomosci-online.pl/miesz...
# 85    https://warszawa.nieruchomosci-online.pl/miesz...
# 316   https://warszawa.nieruchomosci-online.pl/miesz...
# 4499  https://warszawa.nieruchomosci-online.pl/miesz...
# 1676  https://warszawa.nieruchomosci-online.pl/miesz...

# %% [markdown]
# #### portal_name

# %%
display_sample_with_columns_list(sorted_df_after_rename, ['portal_name'])
# Out:
# UNIQUE VALUES FOR 'morizon_portal_name': 1
# Percentage of 'none' values for 'morizon_portal_name': 0.00%
# Unique values in 'morizon_portal_name': ['morizon']
# UNIQUE VALUES FOR 'otodom_portal_name': 2
# Percentage of 'none' values for 'otodom_portal_name': 0.00%
# Unique values in 'otodom_portal_name': ['otodom' nan]
# UNIQUE VALUES FOR 'no_portal_name': 2
# Percentage of 'none' values for 'no_portal_name': 0.00%
# Unique values in 'no_portal_name': ['nieruchomosci online' nan]
#      morizon_portal_name otodom_portal_name        no_portal_name
# 4611             morizon             otodom  nieruchomosci online
# 2248             morizon             otodom  nieruchomosci online
# 2446             morizon             otodom  nieruchomosci online
# 6882             morizon             otodom                   NaN
# 2555             morizon             otodom  nieruchomosci online
# 849              morizon             otodom  nieruchomosci online

# %%
rename_market_type_dict = {
    'otodom':  'otodom',
    'nieruchomosci online': 'no'
}
for data_frame in portal_data_objects:
    change_column_values_with_dict(data_frame.df, 'portal_name', rename_market_type_dict)

otodom.df.portal_name.unique()
# Out:
# array(['otodom'], dtype=object)

# %% [markdown]
# ## Check

# %%
final_column_names = find_common_columns(morizon.df, otodom.df, no.df)
sorted_final_column_names = sorted(final_column_names)
sorted_final_column_names
# Out:
# ['balcony',
#  'balcony_nan',
#  'basement',
#  'basement_nan',
#  'building_type',
#  'building_type_nan',
#  'building_year',
#  'building_year_nan',
#  'district_norm',
#  'elevator',
#  'elevator_nan',
#  'heating_type',
#  'heating_type_nan',
#  'id',
#  'is_parking',
#  'is_primary',
#  'is_primary_nan',
#  'no_rooms',
#  'parking_nan',
#  'portal_name',
#  'price',
#  'property_level',
#  'property_level_nan',
#  'row_price_m2',
#  'total_area',
#  'total_property_level',
#  'total_property_level_nan',
#  'url']

# %%
morizon.df[sorted_final_column_names]
# Out:
#       balcony  balcony_nan  basement  basement_nan building_type  \
# 0         0.0            0         1             0      tenement
# 1         1.0            0         0             0     apartment
# 2         1.0            0         0             0     apartment
# 3         1.0            0         0             0     apartment
# 4         1.0            0         1             0     apartment
# ...       ...          ...       ...           ...           ...
# 7301      0.0            0         1             0      tenement
# 7302      0.0            0         1             0      tenement
# 7303      0.0            0         1             0       UNKNOWN
# 7304      1.0            0         0             0     apartment
# 7305      1.0            0         0             0     apartment
#
#       building_type_nan  building_year  building_year_nan   district_norm  \
# 0                     0           1953                  0         mokotow
# 1                     0           2022                  0         bielany
# 2                     0           2022                  0         ursynow
# 3                     0           2012                  0         mokotow
# 4                     0           2004                  0         ursynow
# ...                 ...            ...                ...             ...
# 7301                  0           1952                  0     srodmiescie
# 7302                  0           1952                  0          wlochy
# 7303                  1           1990                  0          ochota
# 7304                  0           2024                  0  praga poludnie
# 7305                  0           2024                  0          wlochy
#
#       elevator  ...  parking_nan portal_name      price property_level  \
# 0            1  ...            0     morizon  1540000.0            4.0
# 1            1  ...            0     morizon  1560000.0            3.0
# 2            1  ...            0     morizon  1560000.0            3.0
# 3            1  ...            0     morizon  1650000.0            5.0
# 4            1  ...            0     morizon  1660000.0            1.0
# ...        ...  ...          ...         ...        ...            ...
# 7301         0  ...            0     morizon  1395000.0            3.0
# 7302         0  ...            0     morizon  1395000.0            3.0
# 7303         0  ...            0     morizon  1399000.0            1.0
# 7304         0  ...            0     morizon  1400000.0            1.0
# 7305         0  ...            0     morizon  1400000.0            1.0
#
#       property_level_nan  row_price_m2  total_area  total_property_level  \
# 0                      0         16862        91.0                   5.0
# 1                      0         22125        70.0                   5.0
# 2                      0         22125       110.0                   5.0
# 3                      0         21484        76.0                   7.0
# 4                      0         19302        86.0                   5.0
# ...                  ...           ...         ...                   ...
# 7301                   0         32299        43.0                   3.0
# 7302                   0         32299       100.0                   3.0
# 7303                   0         16695        83.0                   1.0
# 7304                   0         17113        81.0                   4.0
# 7305                   0         17113       100.0                   4.0
#
#       total_property_level_nan  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 7301                         0
# 7302                         0
# 7303                         0
# 7304                         0
# 7305                         0
#
#                                                     url
# 0     https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 1     https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 2     https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 3     https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 4     https://www.morizon.pl/oferta/sprzedaz-mieszka...
# ...                                                 ...
# 7301  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 7302  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 7303  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 7304  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 7305  https://www.morizon.pl/oferta/sprzedaz-mieszka...
#
# [4802 rows x 28 columns]

# %%
otodom.df[sorted_final_column_names]
# Out:
#        balcony  balcony_nan  basement  basement_nan building_type  \
# 0          1.0            0         0             1         block
# 1          1.0            0         0             1     apartment
# 2          1.0            0         0             1      tenement
# 3          1.0            0         0             1     apartment
# 4          0.0            1         0             1      tenement
# ...        ...          ...       ...           ...           ...
# 11337      1.0            0         1             0     apartment
# 11338      1.0            0         1             0     apartment
# 11339      1.0            0         1             0         block
# 11340      1.0            0         0             1         block
# 11341      1.0            0         1             0         block
#
#        building_type_nan  building_year  building_year_nan district_norm  \
# 0                      0           2008                  0        bemowo
# 1                      0           2017                  0      targowek
# 2                      0           2007                  0      targowek
# 3                      0           2014                  0     bialoleka
# 4                      0           1949                  0       mokotow
# ...                  ...            ...                ...           ...
# 11337                  0           2019                  0       ursynow
# 11338                  0           2010                  0       mokotow
# 11339                  0           2008                  0       UNKNOWN
# 11340                  0           2001                  0     bialoleka
# 11341                  0           1969                  0      targowek
#
#        elevator  ...  parking_nan portal_name      price  property_level  \
# 0             0  ...            0      otodom  1290000.0             1.0
# 1             1  ...            0      otodom  1260000.0             4.0
# 2             1  ...            1      otodom  1283710.0             4.0
# 3             1  ...            0      otodom  1350000.0             2.0
# 4             0  ...            1      otodom  1580000.0             3.0
# ...         ...  ...          ...         ...        ...             ...
# 11337         1  ...            0      otodom  1100000.0             3.0
# 11338         1  ...            0      otodom   700000.0             3.0
# 11339         1  ...            0      otodom  1000000.0            10.0
# 11340         1  ...            0      otodom   699000.0             4.0
# 11341         0  ...            0      otodom   800000.0             4.0
#
#        property_level_nan  row_price_m2  total_area  total_property_level  \
# 0                       0         16290       79.19                   7.0
# 1                       0         18491       68.14                  11.0
# 2                       0         15500       82.82                   5.0
# 3                       0         18367       73.50                   3.0
# 4                       0         22332       70.75                   4.0
# ...                   ...           ...         ...                   ...
# 11337                   0         16222       67.81                   4.0
# 11338                   0         33767       89.00                   5.0
# 11339                   0         33333       30.00                   1.0
# 11340                   0         15196       46.00                   6.0
# 11341                   0         14414       55.50                   4.0
#
#        total_property_level_nan  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 11337                         0
# 11338                         0
# 11339                         0
# 11340                         0
# 11341                         0
#
#                                                      url
# 0                    mieszkanie-79-19-m-warszawa-ID4pzV9
# 1      3-pokoje-moderna-osiedle-gotowe-do-wprowadzeni...
# 2       trzypokojowe-mieszkanie-na-pradze-polnoc-ID4pAwp
# 3                  apartament-w-marinie-3-pokoje-ID4pCuq
# 4            mieszkanie-w-sercu-starego-mokotowa-ID4pCJK
# ...                                                  ...
# 11337  3-pok-klobucka-6a-komorka-obok-mieszkania-2gar...
# 11338            apartament-mokotow-chodkiewicza-ID4peUU
# 11339                                          x-ID4p9qQ
# 11340  warszawa-tarchomin-2-pokoje-46m2-po-remoncie-I...
# 11341                                   sprzedam-ID4p6Gg
#
# [10167 rows x 28 columns]

# %%
no.df[sorted_final_column_names]
# Out:
#       balcony  balcony_nan  basement  basement_nan building_type  \
# 0           1            0         1             0       UNKNOWN
# 1           1            0         0             0       UNKNOWN
# 2           0            0         1             0      tenement
# 3           1            0         0             0     apartment
# 4           1            0         0             0       UNKNOWN
# ...       ...          ...       ...           ...           ...
# 7036        0            0         1             0       UNKNOWN
# 7037        0            0         0             0     apartment
# 7038        1            0         1             0       UNKNOWN
# 7040        1            0         0             0       UNKNOWN
# 7041        0            1         0             1       UNKNOWN
#
#       building_type_nan  building_year  building_year_nan   district_norm  \
# 0                     1           1980                  0         ursynow
# 1                     1           2000                  0         mokotow
# 2                     0           1911                  0     srodmiescie
# 3                     0           2023                  0         mokotow
# 4                     1           2018                  0         wilanow
# ...                 ...            ...                ...             ...
# 7036                  1           1950                  0     srodmiescie
# 7037                  0           2019                  0         ursynow
# 7038                  1           2008                  0  praga poludnie
# 7040                  1           2017                  0       bialoleka
# 7041                  1           2003                  0         mokotow
#
#       elevator  ...  parking_nan portal_name      price property_level  \
# 0            0  ...            0          no  1075000.0            1.0
# 1            1  ...            0          no  2110000.0            2.0
# 2            0  ...            1          no  1890000.0            0.0
# 3            1  ...            1          no  1590000.0            4.0
# 4            1  ...            0          no  1530000.0            2.0
# ...        ...  ...          ...         ...        ...            ...
# 7036         0  ...            0          no   678999.0            2.0
# 7037         1  ...            0          no  1090000.0            0.0
# 7038         0  ...            0          no   799000.0            1.0
# 7040         1  ...            0          no   820000.0            3.0
# 7041         0  ...            1          no  1770000.0            8.0
#
#       property_level_nan  row_price_m2  total_area  total_property_level  \
# 0                      0         12647       85.00                   4.0
# 1                      0         19905      106.00                   7.0
# 2                      0         34363       55.00                   4.0
# 3                      0         24267       65.52                   8.0
# 4                      0         21932       69.76                   4.0
# ...                  ...           ...         ...                   ...
# 7036                   0         19970       34.00                   4.0
# 7037                   0         23226       46.93                   3.0
# 7038                   0         15380       51.95                   2.0
# 7040                   0         13921       58.90                   5.0
# 7041                   0         25652       69.00                 100.0
#
#       total_property_level_nan  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 7036                         0
# 7037                         0
# 7038                         0
# 7040                         0
# 7041                         1
#
#                                                     url
# 0     https://warszawa.nieruchomosci-online.pl/miesz...
# 1     https://warszawa.nieruchomosci-online.pl/miesz...
# 2     https://warszawa.nieruchomosci-online.pl/miesz...
# 3     https://warszawa.nieruchomosci-online.pl/miesz...
# 4     https://warszawa.nieruchomosci-online.pl/miesz...
# ...                                                 ...
# 7036  https://warszawa.nieruchomosci-online.pl/miesz...
# 7037  https://warszawa.nieruchomosci-online.pl/miesz...
# 7038  https://warszawa.nieruchomosci-online.pl/miesz...
# 7040  https://warszawa.nieruchomosci-online.pl/miesz...
# 7041  https://warszawa.nieruchomosci-online.pl/miesz...
#
# [6861 rows x 28 columns]

# %%
# Collecting columns from each DataFrame

#unmatched_columns_names
columns_dict = {name: set(df.columns) for name, df in objects_dataframes.items()}

# Determining common columns
common_columns = set.intersection(*columns_dict.values())
print("Common columns for all platforms:")
for column in common_columns:
    print(f" - {column}")

# Determining unique columns
unique_columns = set.union(*columns_dict.values()) - common_columns
print("\nUnique columns (not common for all platforms):")
for column in unique_columns:
    print(f" - {column}")

# Checking common and unique columns in DataFrames
# Collecting columns from each DataFrame
columns_dict = {name: set(df.columns) for name, df in objects_dataframes.items()}

# Determining common columns
common_columns = set.intersection(*columns_dict.values())
print("Common columns for all platforms:")
for column in common_columns:
    print(f" - {column}")

# Determining unique columns
unique_columns = set.union(*columns_dict.values()) - common_columns
print("\nUnique columns (not common for all platforms):")
for column in unique_columns:
    print(f" - {column}")
# Out:
# Common columns for all platforms:
#  - is_primary_nan
#  - total_area
#  - basement
#  - elevator
#  - balcony
#  - property_level
#  - heating_type_nan
#  - balcony_nan
#  - row_price_m2
#  - total_property_level
#  - parking_nan
#  - url
#  - building_type_nan
#  - building_year
#  - heating_type
#  - price
#  - is_primary
#  - total_property_level_nan
#  - elevator_nan
#  - id
#  - is_parking
#  - no_rooms
#  - district_norm
#  - building_type
#  - property_level_nan
#  - building_year_nan
#  - portal_name
#  - basement_nan
#
# Unique columns (not common for all platforms):
# Common columns for all platforms:
#  - is_primary_nan
#  - total_area
#  - basement
#  - elevator
#  - balcony
#  - property_level
#  - heating_type_nan
#  - balcony_nan
#  - row_price_m2
#  - total_property_level
#  - parking_nan
#  - url
#  - building_type_nan
#  - building_year
#  - heating_type
#  - price
#  - is_primary
#  - total_property_level_nan
#  - elevator_nan
#  - id
#  - is_parking
#  - no_rooms
#  - district_norm
#  - building_type
#  - property_level_nan
#  - building_year_nan
#  - portal_name
#  - basement_nan
#
# Unique columns (not common for all platforms):

# %%
to_int_columns = ['is_parking','no_rooms','property_level_nan','building_year_nan','property_level','total_property_level_nan','is_primary','building_year', 'elevator_nan','balcony','total_property_level','heating_type_nan','basement_nan','parking_nan','building_type_nan']

for data_frame in portal_data_objects:
    data_frame.convert_column_types(to_int_columns, int)

# %%
combined_df = pd.DataFrame(columns=list(common_columns))
for name, data_frame in objects_dataframes.items():

    combined_df = pd.concat([combined_df, data_frame[list(common_columns)]], ignore_index=True)

# %%
combined_df.to_csv('all_platforms_data.csv', index=False)

all_platforms_data = pd.read_csv('all_platforms_data.csv')
all_platforms_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21830 entries, 0 to 21829
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   is_primary_nan            21830 non-null  int64
#  1   total_area                21830 non-null  float64
#  2   basement                  21830 non-null  int64
#  3   elevator                  21830 non-null  int64
#  4   balcony                   21830 non-null  int64
#  5   property_level            21830 non-null  int64
#  6   heating_type_nan          21830 non-null  int64
#  7   balcony_nan               21830 non-null  int64
#  8   row_price_m2              21830 non-null  int64
#  9   total_property_level      21830 non-null  int64
#  10  parking_nan               21830 non-null  int64
#  11  url                       21830 non-null  object
#  12  building_type_nan         21830 non-null  int64
#  13  building_year             21830 non-null  int64
#  14  heating_type              21830 non-null  object
#  15  price                     21830 non-null  float64
#  16  is_primary                21830 non-null  int64
#  17  total_property_level_nan  21830 non-null  int64
#  18  elevator_nan              21830 non-null  int64
#  19  id                        21830 non-null  object
#  20  is_parking                21830 non-null  int64
#  21  no_rooms                  21830 non-null  int64
#  22  district_norm             21830 non-null  object
#  23  building_type             21830 non-null  object
#  24  property_level_nan        21830 non-null  int64
#  25  building_year_nan         21830 non-null  int64
#  26  portal_name               21830 non-null  object
#  27  basement_nan              21830 non-null  int64
# dtypes: float64(2), int64(20), object(6)
# memory usage: 4.7+ MB

# %%
all_platforms_data.sample(10)
# Out:
#        is_primary_nan  total_area  basement  elevator  balcony  \
# 533                 0       41.00         0         0        1
# 4252                0       46.00         1         1        1
# 12938               0       53.42         0         1        1
# 14602               0       55.00         1         1        1
# 16342               0       53.97         0         1        0
# 8713                0       41.00         0         1        1
# 17299               0       65.78         0         1        1
# 10320               0       27.00         0         1        1
# 19810               0       62.50         1         1        1
# 21799               0       42.00         1         0        0
#
#        property_level  heating_type_nan  balcony_nan  row_price_m2  \
# 533               100                 1            0         15254
# 4252                6                 0            0         18000
# 12938               3                 0            0         11100
# 14602               0                 0            0         11618
# 16342               0                 1            1         14508
# 8713                6                 1            0         14610
# 17299               1                 0            0         28868
# 10320             100                 1            0         21667
# 19810               6                 0            0         13600
# 21799               4                 0            0         19999
#
#        total_property_level  ...  elevator_nan             id  is_parking  \
# 533                     100  ...             0  mzn2043485631           1
# 4252                      7  ...             0  mzn2043417644           1
# 12938                     5  ...             0       65061435           1
# 14602                     2  ...             0       64572046           1
# 16342                     3  ...             0       24374637           0
# 8713                    100  ...             0       65103186           0
# 17299                     2  ...             0       24567045           1
# 10320                    16  ...             0       65019062           0
# 19810                    11  ...             0       24690985           0
# 21799                     4  ...             0       24687558           0
#
#        no_rooms district_norm  building_type  property_level_nan  \
# 533           2     bialoleka        UNKNOWN                   1
# 4252          2        bemowo          block                   0
# 12938         3     rembertow        UNKNOWN                   0
# 14602         4     bialoleka          block                   0
# 16342         3     bialoleka        UNKNOWN                   0
# 8713          2      targowek          block                   0
# 17299         3       bielany      apartment                   0
# 10320         2          wola          block                   0
# 19810         3     bialoleka        UNKNOWN                   0
# 21799         2   srodmiescie       tenement                   0
#
#        building_year_nan  portal_name basement_nan
# 533                    0      morizon            0
# 4252                   0      morizon            0
# 12938                  0       otodom            1
# 14602                  0       otodom            0
# 16342                  0           no            1
# 8713                   0       otodom            1
# 17299                  0           no            0
# 10320                  0       otodom            1
# 19810                  0           no            0
# 21799                  0           no            0
#
# [10 rows x 28 columns]

# %%
numeric_columns = [column for column in combined_df.columns if pd.api.types.is_numeric_dtype(all_platforms_data[column]) and "_nan" not in column]
numeric_columns
# Out:
# ['total_area',
#  'basement',
#  'elevator',
#  'balcony',
#  'property_level',
#  'row_price_m2',
#  'total_property_level',
#  'building_year',
#  'price',
#  'is_primary',
#  'is_parking',
#  'no_rooms']

# %%
numeric_columns_outliers = [
 'price',
 'row_price_m2',
 'total_area', 
 'building_year'
]

# %% [markdown]
# # Remove outliers

# %%
num_rows_start = combined_df.shape[0]
for column in numeric_columns_outliers:
    print(column)
    Q1 = combined_df[column].quantile(0.25)
    Q3 = combined_df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    num_rows_before = combined_df.shape[0]

    outliers = combined_df[(combined_df[column] < lower_bound) | (combined_df[column] > upper_bound)]
    combined_df = combined_df[(combined_df[column] >= lower_bound) & (combined_df[column] <= upper_bound)]
 
    num_rows_after = combined_df.shape[0]
    
    print(f"For column {column}: {num_rows_before} rows before, {num_rows_after} rows after")
    print(f"{num_rows_before - num_rows_after} rows removed")

num_rows_stop = combined_df.shape[0]
final = num_rows_start - num_rows_stop
print(f'DELETED: {final} ROWS, - {round(final /num_rows_start * 100, 2)}%')
# Out:
# price
# For column price: 21830 rows before, 20278 rows after
# 1552 rows removed
# row_price_m2
# For column row_price_m2: 20278 rows before, 19712 rows after
# 566 rows removed
# total_area
# For column total_area: 19712 rows before, 18954 rows after
# 758 rows removed
# building_year
# For column building_year: 18954 rows before, 18883 rows after
# 71 rows removed
# DELETED: 2947 ROWS, - 13.5%

# %%
combined_df.to_csv('all_platforms_data.csv', index=False)
#underwriting base
all_platforms_data = pd.read_csv('all_platforms_data.csv')
all_platforms_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18883 entries, 0 to 18882
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   is_primary_nan            18883 non-null  int64
#  1   total_area                18883 non-null  float64
#  2   basement                  18883 non-null  int64
#  3   elevator                  18883 non-null  int64
#  4   balcony                   18883 non-null  int64
#  5   property_level            18883 non-null  int64
#  6   heating_type_nan          18883 non-null  int64
#  7   balcony_nan               18883 non-null  int64
#  8   row_price_m2              18883 non-null  int64
#  9   total_property_level      18883 non-null  int64
#  10  parking_nan               18883 non-null  int64
#  11  url                       18883 non-null  object
#  12  building_type_nan         18883 non-null  int64
#  13  building_year             18883 non-null  int64
#  14  heating_type              18883 non-null  object
#  15  price                     18883 non-null  float64
#  16  is_primary                18883 non-null  int64
#  17  total_property_level_nan  18883 non-null  int64
#  18  elevator_nan              18883 non-null  int64
#  19  id                        18883 non-null  object
#  20  is_parking                18883 non-null  int64
#  21  no_rooms                  18883 non-null  int64
#  22  district_norm             18883 non-null  object
#  23  building_type             18883 non-null  object
#  24  property_level_nan        18883 non-null  int64
#  25  building_year_nan         18883 non-null  int64
#  26  portal_name               18883 non-null  object
#  27  basement_nan              18883 non-null  int64
# dtypes: float64(2), int64(20), object(6)
# memory usage: 4.0+ MB
